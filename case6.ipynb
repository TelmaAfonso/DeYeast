# %% [markdown]
# # Case 6 Report
# This report contains the results with case 6 simulations.

# %%
import warnings
from case_6 import *
pd.set_option('display.max_colwidth', -1)
warnings.filterwarnings('ignore')
#Initialization
case6 = Case6()
case6.model = case6.loadObjectFromFile('model_yeast_76.sav')
case6.model.solver = 'optlang-cplex'
case6.setMedium('MINIMAL')

# %% [markdown]
# ## General datasets

# %%
exp_dataset, reactions = case6.loadExperimentalRes('Results/Case 6/case6_experimental_fluxes.csv')
# NO EXPERIMENTAL ETHANOL FLUXES TO ADJUST O2 LB

# %% [markdown]
# # Wild Type

# %% [markdown]
# ## Flux Balance Analysis (FBA) Simulation

# %%
wt_fba_res, wt_fba_exp_sim, wt_fba_exp_sim_errors = case6.simulationPipeline(exp_dataset.ix[:,1], type = 'fba', res_exists = True)
pd.concat([reactions, wt_fba_exp_sim_errors], axis = 1, join = 'inner')
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0718     (S)-Malate-mit <==> Pyruvate-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            WT Real Flux    fluxes  Abs Error   Rel Error
# Yeast7_ID
# r_0534     1.5000        1.500000  0.000000   0.000000
# r_0962    -1.8315       -0.797829  1.033671   56.438513
# r_0718     0.1005        0.000000  0.100500   100.000000
# r_2131     0.8985        0.107049  0.791451   88.085833
# r_0713     0.2745        0.144758  0.129742   47.264684
# r_0300    -0.8985       -0.144758  0.753742   83.888877
# r_1022    -0.7365       -0.000000  0.736500   100.000000
# r_0454     0.7365       -0.000000  0.736500   100.000000
# r_0366     1.9065        0.872935  1.033565   54.212676
# r_1054    -0.9045       -0.932580  0.028080   3.104520
# r_0486     1.9065        1.837893  0.068607   3.598583
# r_0450     0.9045        0.933942  0.029442   3.255083
# r_0452    -0.7365       -0.053366  0.683134   92.754092
# r_0302     0.8985        0.144758  0.753742   83.888877
# r_0892    -1.9065       -1.837893  0.068607   3.598583
# r_0893    -1.9065       -0.872935  1.033565   54.212676
# r_0889     0.6630        0.020629  0.642371   96.888558
# r_1049    -0.1815       -0.004889  0.176611   97.306610
# r_1048     0.1815        0.004889  0.176611   97.306610
# r_1050    -0.4005       -0.032665  0.367835   91.843982
# r_0466     0.6630        0.020629  0.642371   96.888558
# r_0467     0.5040        1.076571  0.572571   113.605415
# r_0886     0.9045        0.933942  0.029442   3.255083
# r_0958     0.4095        0.301848  0.107652   26.288722
# r_0091     0.6630        0.020629  0.642371   96.888558
# r_0832     0.7365        0.000001  0.736499   99.999846
# r_1239     0.5370        0.000000  0.537000   100.000000
# r_4041     0.1000        0.142086  0.042086   42.086087

# %% [markdown]
# <p style="float: center; font-size: 9pt; text-align: center; width: 80%;"><img src = "Results/Case 6/wt_fba_exp_sim_plot.png", width = 100%></p>

# %% [markdown]
# ## Parsimonious Flux Balance Analysis (pFBA) Simulation

# %%
wt_pfba_res, wt_pfba_exp_sim, wt_pfba_exp_sim_errors = case6.simulationPipeline(exp_dataset.ix[:,1], type = 'pfba', res_exists = True)
pd.concat([reactions, wt_pfba_exp_sim_errors], axis = 1, join = 'inner')
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0718     (S)-Malate-mit <==> Pyruvate-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            WT Real Flux    fluxes  Abs Error   Rel Error
# Yeast7_ID
# r_0534     1.5000        1.500000  0.000000   0.000000
# r_0962    -1.8315       -0.797842  1.033658   56.437804
# r_0718     0.1005        0.000000  0.100500   100.000000
# r_2131     0.8985        0.107048  0.791452   88.085952
# r_0713     0.2745        0.144757  0.129743   47.265211
# r_0300    -0.8985       -0.144757  0.753743   83.889038
# r_1022    -0.7365       -0.000000  0.736500   100.000000
# r_0454     0.7365       -0.000000  0.736500   100.000000
# r_0366     1.9065        0.872948  1.033552   54.212034
# r_1054    -0.9045       -0.932445  0.027945   3.089530
# r_0486     1.9065        1.837763  0.068737   3.605383
# r_0450     0.9045        0.928777  0.024277   2.684015
# r_0452    -0.7365       -0.053366  0.683134   92.754164
# r_0302     0.8985        0.107048  0.791452   88.085952
# r_0892    -1.9065       -1.837763  0.068737   3.605383
# r_0893    -1.9065       -0.872948  1.033552   54.212034
# r_0889     0.6630        0.021052  0.641948   96.824671
# r_1049    -0.1815       -0.005030  0.176470   97.228808
# r_1048     0.1815        0.000000  0.181500   100.000000
# r_1050    -0.4005       -0.032523  0.367977   91.879335
# r_0466     0.6630        0.021052  0.641948   96.824671
# r_0467     0.5040        1.076152  0.572152   113.522172
# r_0886     0.9045        0.928777  0.024277   2.684015
# r_0958     0.4095        0.301845  0.107655   26.289459
# r_0091     0.6630        0.021052  0.641948   96.824671
# r_0832     0.7365        0.000001  0.736499   99.999846
# r_1239     0.5370        0.000000  0.537000   100.000000
# r_4041     0.1000        0.142085  0.042085   42.084666

# %% [markdown]
# <p style="float: center; font-size: 9pt; text-align: center; width: 80%;"><img src = "Results/Case 6/wt_pfba_exp_sim_plot.png", width = 100%></p>

# %% [markdown]
# ## Flux Variability Analysis (FVA) Simulation

# %%
wt_fva_res, wt_fva_exp_sim, _ = case6.simulationPipeline(exp_dataset.ix[:,1], type = 'fva', res_exists = True)
pd.concat([reactions, wt_fva_exp_sim], axis = 1, join = 'inner')
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0718     (S)-Malate-mit <==> Pyruvate-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            WT Real Flux      maximum     minimum
# Yeast7_ID
# r_0534     1.5000        1.500255     1.499985
# r_0962    -1.8315       -0.798523    -0.797578
# r_0718     0.1005        0.001755     0.000000
# r_2131     0.8985        0.108803     0.105877
# r_0713     0.2745        1000.000000  0.144118
# r_0300    -0.8985       -0.145459    -0.144663
# r_1022    -0.7365       -0.000702    -0.000000
# r_0454     0.7365       -5.805028    -0.000000
# r_0366     1.9065        0.873629     0.872684
# r_1054    -0.9045       -0.933996    -0.932241
# r_0486     1.9065        1.839315     1.837559
# r_0450     0.9045        0.935358    -0.000351
# r_0452    -0.7365       -0.053867    -0.052727
# r_0302     0.8985        1000.000000 -999.855244
# r_0892    -1.9065       -1.839315    -1.837559
# r_0893    -1.9065       -0.873629    -0.872684
# r_0889     0.6630        0.021664     0.016397
# r_1049    -0.1815       -0.005233    -0.003478
# r_1048     0.1815        0.005233    -0.931881
# r_1050    -0.4005       -0.032320    -0.034075
# r_0466     0.6630        0.021664     0.016397
# r_0467     0.5040        1.080806     1.075540
# r_0886     0.9045        0.935358     0.000000
# r_0958     0.4095        0.308865     0.301689
# r_0091     0.6630        0.021664     0.016399
# r_0832     0.7365        0.000703     0.000000
# r_1239     0.5370        0.000638     0.000000
# r_4041     0.1000        0.142085     0.142085

# %% [markdown]
# # MAE1 Deletion

# %% [markdown]
# ## Flux Balance Analysis (FBA) Simulation

# %%
mae1_fba_res, mae1_fba_exp_sim, mae1_fba_exp_sim_errors = case6.simulationPipeline(exp_dataset.ix[:,0], geneko = mae1, type = 'fba', res_exists = True)
pd.concat([reactions, mae1_fba_exp_sim_errors], axis = 1, join = 'inner')
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0718     (S)-Malate-mit <==> Pyruvate-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            MAE1 Real Flux       fluxes   Abs Error      Rel Error
# Yeast7_ID
# r_0534     1.5000          1.500000     0.000000    0.000000
# r_0962    -1.8405         -0.759511     1.080989    58.733458
# r_0718     0.0000          0.000000     0.000000   NaN
# r_2131     0.8835          0.127334     0.756166    85.587502
# r_0713     0.3990          0.141874     0.257126    64.442679
# r_0300    -0.8835         -0.141874     0.741626    83.941855
# r_1022    -0.7125         -0.000000     0.712500    100.000000
# r_0454     0.7125         -5.734063     6.446563    904.780755
# r_0366     1.9155          0.877958     1.037542    54.165573
# r_1054    -0.9150         -0.928942     0.013942    1.523710
# r_0486     1.9155          1.823687     0.091813    4.793184
# r_0450     0.9150          0.930277     0.015277    1.669579
# r_0452    -0.7110         -0.052303     0.658697    92.643792
# r_0302     0.8835          1000.000000  999.116500  113086.191285
# r_0892    -1.9155         -1.823687     0.091813    4.793184
# r_0893    -1.9155         -0.877958     1.037542    54.165573
# r_0889     0.6315          0.042637     0.588863    93.248353
# r_1049    -0.1710         -0.019737     0.151263    88.457893
# r_1048     0.1710          0.019737     0.151263    88.457893
# r_1050    -0.3795         -0.039487     0.340013    89.595028
# r_0466     0.6315          0.042637     0.588863    93.248353
# r_0467     0.5355          1.062590     0.527090    98.429590
# r_0886     0.9150          0.930277     0.015277    1.669579
# r_0958     0.3180          0.273414     0.044586    14.020875
# r_0091     0.6315          0.042637     0.588863    93.248353
# r_0832     0.7125          0.000001     0.712499    99.999844
# r_1239     0.5715          0.000000     0.571500    100.000000
# r_4041     0.1000          0.139255     0.039255    39.254611

# %% [markdown]
# <p style="float: center; font-size: 9pt; text-align: center; width: 80%;"><img src = "Results/Case 6/mae1_fba_exp_sim_plot.png", width = 100%></p>

# %% [markdown]
# ## Parsimonious Flux Balance Analysis (pFBA) Simulation

# %%
mae1_pfba_res, mae1_pfba_exp_sim, mae1_pfba_exp_sim_errors = case6.simulationPipeline(exp_dataset.ix[:,0], geneko = mae1, type = 'pfba', res_exists = True)
pd.concat([reactions, mae1_pfba_exp_sim_errors], axis = 1, join = 'inner')
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0718     (S)-Malate-mit <==> Pyruvate-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            MAE1 Real Flux    fluxes  Abs Error   Rel Error
# Yeast7_ID
# r_0534     1.5000          1.500000  0.000000   0.000000
# r_0962    -1.8405         -0.759524  1.080976   58.732754
# r_0718     0.0000          0.000000  0.000000  NaN
# r_2131     0.8835          0.127333  0.756167   85.587647
# r_0713     0.3990          0.141872  0.257128   64.443034
# r_0300    -0.8835         -0.141872  0.741628   83.942016
# r_1022    -0.7125         -0.000000  0.712500   100.000000
# r_0454     0.7125         -0.000000  0.712500   100.000000
# r_0366     1.9155          0.877970  1.037530   54.164958
# r_1054    -0.9150         -0.928806  0.013806   1.508876
# r_0486     1.9155          1.823557  0.091943   4.799954
# r_0450     0.9150          0.910263  0.004737   0.517741
# r_0452    -0.7110         -0.052302  0.658698   92.643866
# r_0302     0.8835          0.127333  0.756167   85.587647
# r_0892    -1.9155         -1.823557  0.091943   4.799954
# r_0893    -1.9155         -0.877970  1.037530   54.164958
# r_0889     0.6315          0.043061  0.588439   93.181231
# r_1049    -0.1710         -0.019878  0.151122   88.375298
# r_1048     0.1710          0.000000  0.171000   100.000000
# r_1050    -0.3795         -0.039345  0.340155   89.632401
# r_0466     0.6315          0.043061  0.588439   93.181231
# r_0467     0.5355          1.062171  0.526671   98.351172
# r_0886     0.9150          0.910263  0.004737   0.517741
# r_0958     0.3180          0.273411  0.044589   14.021735
# r_0091     0.6315          0.043061  0.588439   93.181231
# r_0832     0.7125          0.000001  0.712499   99.999844
# r_1239     0.5715          0.000000  0.571500   100.000000
# r_4041     0.1000          0.139253  0.039253   39.253218

# %% [markdown]
# <p style="float: center; font-size: 9pt; text-align: center; width: 80%;"><img src = "Results/Case 6/mae1_pfba_exp_sim_plot.png", width = 100%></p>

# %% [markdown]
# ## Flux Variability Analysis (FVA) Simulation

# %%
mae1_fva_res, mae1_fva_exp_sim, _ = case6.simulationPipeline(exp_dataset.ix[:,0], geneko = mae1, type = 'fva', res_exists = True)
pd.concat([reactions, mae1_fva_exp_sim], axis = 1, join = 'inner')
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0718     (S)-Malate-mit <==> Pyruvate-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            MAE1 Real Flux      maximum     minimum
# Yeast7_ID
# r_0534     1.5000          1.500255     1.499985
# r_0962    -1.8405         -0.760205    -0.759260
# r_0718     0.0000          0.000000     0.000000
# r_2131     0.8835          0.127346     0.126631
# r_0713     0.3990          1000.000000  0.141779
# r_0300    -0.8835         -0.142574    -0.141779
# r_1022    -0.7125         -0.000702    -0.000000
# r_0454     0.7125         -5.734187    -0.000000
# r_0366     1.9155          0.878652     0.877707
# r_1054    -0.9150         -0.929081    -0.928603
# r_0486     1.9155          1.823832     1.823353
# r_0450     0.9150          0.930639    -0.000351
# r_0452    -0.7110         -0.052804    -0.052272
# r_0302     0.8835          1000.000000 -999.858129
# r_0892    -1.9155         -1.823832    -1.823353
# r_0893    -1.9155         -0.878652    -0.877707
# r_0889     0.6315          0.043671     0.042235
# r_1049    -0.1710         -0.020082    -0.019603
# r_1048     0.1710          0.020082    -0.910909
# r_1050    -0.3795         -0.039141    -0.039620
# r_0466     0.6315          0.043671     0.042235
# r_0467     0.5355          1.062996     1.061560
# r_0886     0.9150          0.930639     0.000000
# r_0958     0.3180          0.273762     0.273255
# r_0091     0.6315          0.043671     0.042235
# r_0832     0.7125          0.000703     0.000000
# r_1239     0.5715          0.000011     0.000000
# r_4041     0.1000          0.139253     0.139253

# %% [markdown]
# ## Linear Minimization of Metabolic Adjustment (LMOMA) Simulation

# %%
mae1_lmoma_res, mae1_lmoma_exp_sim, mae1_lmoma_exp_sim_errors = case6.simulationPipeline(exp_dataset.ix[:,0], geneko = mae1, type = 'lmoma', res_exists = True)
pd.concat([reactions, mae1_lmoma_exp_sim_errors], axis = 1, join = 'inner')
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0718     (S)-Malate-mit <==> Pyruvate-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            MAE1 Real Flux      Sim Flux  Abs Error   Rel Error
# Yeast7_ID
# r_0534     1.5000          1.500000e+00  0.000000   0.000000
# r_0962    -1.8405         -7.595237e-01  1.080976   58.732754
# r_0718     0.0000          0.000000e+00  0.000000  NaN
# r_2131     0.8835          1.273331e-01  0.756167   85.587647
# r_0713     0.3990          1.418723e-01  0.257128   64.443032
# r_0300    -0.8835         -1.418723e-01  0.741628   83.942014
# r_1022    -0.7125         -0.000000e+00  0.712500   100.000000
# r_0454     0.7125         -0.000000e+00  0.712500   100.000000
# r_0366     1.9155          8.779702e-01  1.037530   54.164958
# r_1054    -0.9150         -9.288063e-01  0.013806   1.508882
# r_0486     1.9155          1.823557e+00  0.091943   4.799954
# r_0450     0.9150          9.102627e-01  0.004737   0.517740
# r_0452    -0.7110         -5.230213e-02  0.658698   92.643864
# r_0302     0.8835          1.273331e-01  0.756167   85.587647
# r_0892    -1.9155         -1.823557e+00  0.091943   4.799954
# r_0893    -1.9155         -8.779702e-01  1.037530   54.164958
# r_0889     0.6315          4.306037e-02  0.588440   93.181256
# r_1049    -0.1710         -1.987818e-02  0.151122   88.375332
# r_1048     0.1710         -5.806741e-08  0.171000   100.000034
# r_1050    -0.3795         -3.934510e-02  0.340155   89.632384
# r_0466     0.6315          4.306037e-02  0.588440   93.181256
# r_0467     0.5355          1.062171e+00  0.526671   98.351172
# r_0886     0.9150          9.102627e-01  0.004737   0.517740
# r_0958     0.3180          2.734107e-01  0.044589   14.021787
# r_0091     0.6315          4.306037e-02  0.588440   93.181256
# r_0832     0.7125          1.114026e-06  0.712499   99.999844
# r_1239     0.5715          0.000000e+00  0.571500   100.000000
# r_4041     0.1000          1.392532e-01  0.039253   39.253219

# %% [markdown]
# <p style="float: center; font-size: 9pt; text-align: center; width: 80%;"><img src = "Results/Case 6/mae1_lmoma_exp_sim_plot.png", width = 100%></p>
