# %% [markdown]
# # Case 13 Report
# This report contains the results with case 13 simulations.

# %%
import warnings
from case_13 import *

pd.set_option('display.max_colwidth', -1)
warnings.filterwarnings('ignore')

#Initialization
case13 = Case13()
case13.model = case13.loadObjectFromFile('model_yeast_76.sav')
case13.model.solver = 'optlang-cplex'
case13.setMedium('MINERAL')
case13.dictsForCase13()

# %% [markdown]
# ## General datasets

# %%
#General datasets
exp_dataset, reactions = case13.loadExperimentalRes('Results/Case 13/case13_experimental_fluxes.csv')
pd.DataFrame(reactions)
# Out:
#                                                                                                                  Reaction
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0961     Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0959     Pyruvate <==> Acetaldehyde
# r_2115     Acetaldehyde <==> Ethanol
# r_2116     Acetaldehyde <==> Acetate
# r_0112     Acetate <==> Acetyl-CoA
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0716     (S)-Malate <==> Glyoxylate-cyt + Acetyl-CoA
# r_0662     Isocitrate-cyt <==> Succinate + Glyoxylate-cyt
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0884     Oxaloacetate <==> Phosphoenolpyruvate + CO2
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0984     D-Ribulose-5-phosphate <==> D-Xylulose-5-phosphate
# r_0982     D-Ribose-5-phosphate <==> D-Ribulose-5-phosphate
# r_0718     (S)-Malate-mit <==> Pyruvate + CO2
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_2034     Pyruvate <==> Pyruvate-mit
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass

# %% [markdown]
# # Oxidative Growth

# %% [markdown]
# ## Flux Balance Analysis (FBA) Simulation

# %%
o_exp_df = case13.getColumnWithoutNAs(exp_dataset, 0, 'X')
# NO EtOH fluxes available for O2 flux estimation

o_fba_res, o_fba_exp_sim, o_fba_exp_sim_errors = case13.simulationPipeline(o_exp_df, cs = 'g_oxidative', type = 'fba', res_exists = True, fname = 'Results/Case 13/res_fba_oxidative_case13.sav')
pd.DataFrame(reactions).join(o_fba_exp_sim_errors, how = 'inner')
# Out:
#                                                                                                               Reaction  \
# r_0091  D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0112  Acetate <==> Acetyl-CoA
# r_0300  Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_0302  Citrate <==> Isocitrate
# r_0366  2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0450  D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452  (S)-Malate-mit <==> Fumarate
# r_0454  Succinate-mit <==> Fumarate
# r_0466  D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467  D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0486  D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0534  D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0713  (S)-Malate-mit <==> Oxaloacetate-mit
# r_0718  (S)-Malate-mit <==> Pyruvate + CO2
# r_0832  2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0886  D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0889  6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_0892  3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893  2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0958  Pyruvate + CO2 <==> Oxaloacetate
# r_0958  Pyruvate + CO2 <==> Oxaloacetate
# r_0959  Pyruvate <==> Acetaldehyde
# r_0961  Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_0962  Pyruvate <==> Phosphoenolpyruvate
# r_1022  Succinate-mit + CoA <==> Succinyl-CoA
# r_1048  Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1049  Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1050  D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_1054  D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_1239  Oxaloacetate <==> Oxaloacetate-mit
# r_2034  Pyruvate <==> Pyruvate-mit
# r_2116  Acetaldehyde <==> Acetate
# r_2131  Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_4041  Biomass
#
#         oxidative exp flux    Sim Flux    Abs Error     Rel Error
# r_0091  0.8533              0.021454    0.831846     97.485759
# r_0112  1.1482              0.035344    1.112856     96.921803
# r_0300 -1.1404             -0.150549    0.989851     86.798599
# r_0302  1.1404             -999.849451  1000.989851  87775.328939
# r_0366  2.0077              0.907853    1.099847     54.781454
# r_0450  0.9391              0.971300    0.032200     3.428806
# r_0452 -0.9890             -0.055501    0.933499     94.388194
# r_0454  0.9890             -0.000000    0.989000     100.000000
# r_0466  0.8533              0.021454    0.831846     97.485759
# r_0467  0.3931              1.119634    0.726534     184.821710
# r_0486  2.0920              1.911409    0.180591     8.632470
# r_0534  1.5600              1.560000    0.000000     0.000000
# r_0713  0.9890              0.150549    0.838451     84.777676
# r_0718  0.1123              0.000000    0.112300     100.000000
# r_0832  0.9890              0.000001    0.988999     99.999880
# r_0886  0.9391              0.971300    0.032200     3.428806
# r_0889  0.8533              0.021454    0.831846     97.485759
# r_0892 -2.0920             -1.911409    0.180591     8.632470
# r_0893 -2.0077             -0.907853    1.099847     54.781454
# r_0958  0.3713              0.313922    0.057378     15.453383
# r_0958  0.3713              0.313922    0.057378     15.453383
# r_0959  1.1435              0.026877    1.116623     97.649614
# r_0961  0.3401              0.254861    0.085239     25.063034
# r_0962 -1.9391             -0.829742    1.109358     57.209954
# r_1022 -0.9890             -0.000000    0.989000     100.000000
# r_1048  0.2917              0.005084    0.286616     98.257099
# r_1049 -0.2917             -0.005084    0.286616     98.257099
# r_1050 -0.2543             -0.033971    0.220329     86.641194
# r_1054 -0.9095             -0.969884    0.060384     6.639208
# r_1239  0.2621              0.000000    0.262100     100.000000
# r_2034  0.4212              0.000000    0.421200     100.000000
# r_2116  1.1482              0.000000    1.148200     100.000000
# r_2131  1.1404              0.111331    1.029069     90.237570
# r_4041  0.1500              0.147770    0.002230     1.486980

# %% [markdown]
# <p style="float: center; font-size: 9pt; text-align: center; width: 80%;"><img src = "Results/Case 13/o_fba_exp_sim_plot.png", width = 100%></p>

# %% [markdown]
# ## Parsimonious Flux Balance Analysis (pFBA) Simulation

# %%
o_pfba_res, o_pfba_exp_sim, o_pfba_exp_sim_errors = case13.simulationPipeline(o_exp_df, cs = 'g_oxidative',type = 'pfba', res_exists = True, fname = 'Results/Case 13/res_pfba_oxidative_case13.sav')
pd.DataFrame(reactions).join(o_pfba_exp_sim_errors, how = 'inner')
# Out:
#                                                                                                               Reaction  \
# r_0091  D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0112  Acetate <==> Acetyl-CoA
# r_0300  Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_0302  Citrate <==> Isocitrate
# r_0366  2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0450  D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452  (S)-Malate-mit <==> Fumarate
# r_0454  Succinate-mit <==> Fumarate
# r_0466  D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467  D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0486  D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0534  D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0713  (S)-Malate-mit <==> Oxaloacetate-mit
# r_0718  (S)-Malate-mit <==> Pyruvate + CO2
# r_0832  2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0886  D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0889  6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_0892  3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893  2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0958  Pyruvate + CO2 <==> Oxaloacetate
# r_0958  Pyruvate + CO2 <==> Oxaloacetate
# r_0959  Pyruvate <==> Acetaldehyde
# r_0961  Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_0962  Pyruvate <==> Phosphoenolpyruvate
# r_1022  Succinate-mit + CoA <==> Succinyl-CoA
# r_1048  Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1049  Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1050  D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_1054  D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_1239  Oxaloacetate <==> Oxaloacetate-mit
# r_2034  Pyruvate <==> Pyruvate-mit
# r_2116  Acetaldehyde <==> Acetate
# r_2131  Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_4041  Biomass
#
#         oxidative exp flux  Sim Flux  Abs Error   Rel Error
# r_0091  0.8533              0.021895  0.831405   97.434135
# r_0112  1.1482              0.035267  1.112933   96.928484
# r_0300 -1.1404             -0.150547  0.989853   86.798731
# r_0302  1.1404              0.111330  1.029070   90.237668
# r_0366  2.0077              0.907865  1.099835   54.780820
# r_0450  0.9391              0.965928  0.026828   2.856777
# r_0452 -0.9890             -0.055500  0.933500   94.388250
# r_0454  0.9890             -0.000000  0.989000   100.000000
# r_0466  0.8533              0.021895  0.831405   97.434135
# r_0467  0.3931              1.119198  0.726098   184.710714
# r_0486  2.0920              1.911274  0.180726   8.638915
# r_0534  1.5600              1.560000  0.000000   0.000000
# r_0713  0.9890              0.150547  0.838453   84.777829
# r_0718  0.1123              0.000000  0.112300   100.000000
# r_0832  0.9890              0.000001  0.988999   99.999880
# r_0886  0.9391              0.965928  0.026828   2.856777
# r_0889  0.8533              0.021895  0.831405   97.434135
# r_0892 -2.0920             -1.911274  0.180726   8.638915
# r_0893 -2.0077             -0.907865  1.099835   54.780820
# r_0958  0.3713              0.313918  0.057382   15.454228
# r_0958  0.3713              0.313918  0.057382   15.454228
# r_0959  1.1435              0.026800  1.116700   97.656315
# r_0961  0.3401              0.254956  0.085144   25.034918
# r_0962 -1.9391             -0.829755  1.109345   57.209257
# r_1022 -0.9890             -0.000000  0.989000   100.000000
# r_1048  0.2917              0.000000  0.291700   100.000000
# r_1049 -0.2917             -0.005231  0.286469   98.206753
# r_1050 -0.2543              0.000000  0.254300   100.000000
# r_1054 -0.9095             -0.969743  0.060243   6.623704
# r_1239  0.2621              0.000000  0.262100   100.000000
# r_2034  0.4212              0.425437  0.004237   1.006037
# r_2116  1.1482              0.000678  1.147522   99.940909
# r_2131  1.1404              0.111330  1.029070   90.237668
# r_4041  0.1500              0.147768  0.002232   1.487965

# %% [markdown]
# <p style="float: center; font-size: 9pt; text-align: center; width: 80%;"><img src = "Results/Case 13/o_pfba_exp_sim_plot.png", width = 100%></p>

# %% [markdown]
# ## Flux Variability Analysis (FVA) Simulation

# %%
o_fva_res, o_fva_exp_sim, _ = case13.simulationPipeline(o_exp_df, cs = 'g_oxidative', type = 'fva', res_exists = True, fname = 'Results/Case 13/res_fva_oxidative_case13.sav')
pd.DataFrame(reactions).join(o_fva_exp_sim, how = 'inner')
# Out:
#                                                                                                               Reaction  \
# r_0091  D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0112  Acetate <==> Acetyl-CoA
# r_0300  Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_0302  Citrate <==> Isocitrate
# r_0366  2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0450  D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452  (S)-Malate-mit <==> Fumarate
# r_0454  Succinate-mit <==> Fumarate
# r_0466  D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467  D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0486  D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0534  D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0713  (S)-Malate-mit <==> Oxaloacetate-mit
# r_0718  (S)-Malate-mit <==> Pyruvate + CO2
# r_0832  2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0886  D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0889  6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_0892  3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893  2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0958  Pyruvate + CO2 <==> Oxaloacetate
# r_0958  Pyruvate + CO2 <==> Oxaloacetate
# r_0959  Pyruvate <==> Acetaldehyde
# r_0961  Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_0962  Pyruvate <==> Phosphoenolpyruvate
# r_1022  Succinate-mit + CoA <==> Succinyl-CoA
# r_1048  Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1049  Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1050  D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_1054  D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_1239  Oxaloacetate <==> Oxaloacetate-mit
# r_2034  Pyruvate <==> Pyruvate-mit
# r_2116  Acetaldehyde <==> Acetate
# r_2131  Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_4041  Biomass
#
#         oxidative exp flux      maximum     minimum
# r_0091  0.8533              0.023606     0.012655
# r_0112  1.1482              0.036317     0.035267
# r_0300 -1.1404             -0.152006    -0.150358
# r_0302  1.1404              1000.000000 -999.849455
# r_0366  2.0077              0.909295     0.907330
# r_0450  0.9391              0.974244    -0.000730
# r_0452 -0.9890             -0.056543    -0.054172
# r_0454  0.9890             -6.037356    -0.000000
# r_0466  0.8533              0.023606     0.012655
# r_0467  0.3931              1.128441     1.117490
# r_0486  2.0920              1.914366     1.910715
# r_0534  1.5600              1.560531     1.559969
# r_0713  0.9890              1000.000000  0.149218
# r_0718  0.1123              0.003650     0.000000
# r_0832  0.9890              0.001461     0.000000
# r_0886  0.9391              0.974244     0.000000
# r_0889  0.8533              0.023606     0.012655
# r_0892 -2.0920             -1.914366    -1.910715
# r_0893 -2.0077             -0.909295    -0.907330
# r_0958  0.3713              0.328517     0.313591
# r_0958  0.3713              0.328517     0.313591
# r_0959  1.1435              0.027476     0.026495
# r_0961  0.3401              0.256316     0.254255
# r_0962 -1.9391             -0.831185    -0.829221
# r_1022 -0.9890             -0.001460    -0.000000
# r_1048  0.2917              0.005802    -0.972093
# r_1049 -0.2917             -0.005802    -0.002151
# r_1050 -0.2543             -0.033253    -0.036904
# r_1054 -0.9095             -0.972828    -0.969178
# r_1239  0.2621              0.001327     0.000000
# r_2034  0.4212              0.426795     0.000000
# r_2116  1.1482              0.001622     0.000000
# r_2131  1.1404              0.114979     0.108895
# r_4041  0.1500              0.147768     0.147767

# %% [markdown]
# # Respiro-fermentative growth

# %% [markdown]
# ## Flux Balance Analysis (FBA) Simulation

# %%
rf_exp_df = case13.getColumnWithoutNAs(exp_dataset, 1, 'X')
# NO EtOH fluxes available for O2 flux estimation

rf_fba_res, rf_fba_exp_sim, rf_fba_exp_sim_errors = case13.simulationPipeline(rf_exp_df, cs = 'g_resp_fermentative', type = 'fba', res_exists = True, fname = 'Results/Case 13/res_fba_resp_fermentative_case13.sav')
pd.DataFrame(reactions).join(rf_fba_exp_sim_errors, how = 'inner')
# Out:
#                                                                                                               Reaction  \
# r_0091  D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0112  Acetate <==> Acetyl-CoA
# r_0300  Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_0302  Citrate <==> Isocitrate
# r_0366  2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0450  D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452  (S)-Malate-mit <==> Fumarate
# r_0454  Succinate-mit <==> Fumarate
# r_0466  D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467  D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0486  D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0534  D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0713  (S)-Malate-mit <==> Oxaloacetate-mit
# r_0718  (S)-Malate-mit <==> Pyruvate + CO2
# r_0832  2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0886  D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0889  6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_0892  3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893  2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0958  Pyruvate + CO2 <==> Oxaloacetate
# r_0958  Pyruvate + CO2 <==> Oxaloacetate
# r_0959  Pyruvate <==> Acetaldehyde
# r_0961  Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_0962  Pyruvate <==> Phosphoenolpyruvate
# r_1022  Succinate-mit + CoA <==> Succinyl-CoA
# r_1048  Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1049  Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1050  D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_1054  D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_1239  Oxaloacetate <==> Oxaloacetate-mit
# r_2034  Pyruvate <==> Pyruvate-mit
# r_2116  Acetaldehyde <==> Acetate
# r_2131  Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_4041  Biomass
#
#         respiro-fermentative exp flux    Sim Flux    Abs Error     Rel Error
# r_0091  1.4504                         0.067388    1.383012     95.353860
# r_0112  0.9555                         0.111016    0.844484     88.381374
# r_0300 -2.6656                        -0.472878    2.192722     82.259995
# r_0302  2.6656                        -999.527122  1002.192722  37597.265997
# r_0366  7.6881                         2.851589    4.836511     62.909057
# r_0450  3.8563                         3.050878    0.805422     20.885877
# r_0452 -2.3128                        -0.174329    2.138471     92.462413
# r_0454  2.3128                        -0.000000    2.312800     100.000000
# r_0466  1.4504                         0.067388    1.383012     95.353860
# r_0467  2.9400                         3.516800    0.576800     19.619032
# r_0486  7.8302                         6.003784    1.826416     23.325281
# r_0534  4.9000                         4.900000    0.000000     0.000000
# r_0713  2.3128                         0.472878    1.839922     79.553892
# r_0718  0.7105                         0.000000    0.710500     100.000000
# r_0832  2.3128                         0.000004    2.312796     99.999839
# r_0886  3.8563                         3.050878    0.805422     20.885877
# r_0889  1.4504                         0.067388    1.383012     95.353860
# r_0892 -7.8302                        -6.003784    1.826416     23.325281
# r_0893 -7.6881                        -2.851589    4.836511     62.909057
# r_0958  1.3426                         0.986036    0.356564     26.557741
# r_0958  1.3426                         0.986036    0.356564     26.557741
# r_0959  4.0621                         0.084420    3.977680     97.921757
# r_0961  2.4255                         0.800524    1.624976     66.995517
# r_0962 -7.5068                        -2.606240    4.900560     65.281609
# r_1022 -2.3128                        -0.000000    2.312800     100.000000
# r_1048  0.4998                         0.015969    0.483831     96.804900
# r_1049 -0.4998                        -0.015969    0.483831     96.804900
# r_1050 -0.4165                        -0.106705    0.309795     74.380509
# r_1054 -3.5819                        -3.046429    0.535471     14.949349
# r_1239  1.0633                         0.000000    1.063300     100.000000
# r_2034  2.0972                         0.000000    2.097200     100.000000
# r_2116  1.6758                         0.000000    1.675800     100.000000
# r_2131  2.6656                         0.349693    2.315907     86.881275
# r_4041  0.3000                         0.464148    0.164148     54.715961

# %% [markdown]
# <p style="float: center; font-size: 9pt; text-align: center; width: 80%;"><img src = "Results/Case 13/rf_fba_exp_sim_plot.png", width = 100%></p>

# %% [markdown]
# ## Parsimonious Flux Balance Analysis (pFBA) Simulation

# %%
rf_pfba_res, rf_pfba_exp_sim, rf_pfba_exp_sim_errors = case13.simulationPipeline(rf_exp_df, cs = 'g_resp_fermentative',type = 'pfba', res_exists = True, fname = 'Results/Case 13/res_pfba_resp_fermentative_case13.sav')
pd.DataFrame(reactions).join(rf_pfba_exp_sim_errors, how = 'inner')
# Out:
#                                                                                                               Reaction  \
# r_0091  D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0112  Acetate <==> Acetyl-CoA
# r_0300  Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_0302  Citrate <==> Isocitrate
# r_0366  2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0450  D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452  (S)-Malate-mit <==> Fumarate
# r_0454  Succinate-mit <==> Fumarate
# r_0466  D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467  D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0486  D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0534  D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0713  (S)-Malate-mit <==> Oxaloacetate-mit
# r_0718  (S)-Malate-mit <==> Pyruvate + CO2
# r_0832  2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0886  D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0889  6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_0892  3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893  2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0958  Pyruvate + CO2 <==> Oxaloacetate
# r_0958  Pyruvate + CO2 <==> Oxaloacetate
# r_0959  Pyruvate <==> Acetaldehyde
# r_0961  Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_0962  Pyruvate <==> Phosphoenolpyruvate
# r_1022  Succinate-mit + CoA <==> Succinyl-CoA
# r_1048  Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1049  Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1050  D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_1054  D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_1239  Oxaloacetate <==> Oxaloacetate-mit
# r_2034  Pyruvate <==> Pyruvate-mit
# r_2116  Acetaldehyde <==> Acetate
# r_2131  Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_4041  Biomass
#
#         respiro-fermentative exp flux  Sim Flux  Abs Error   Rel Error
# r_0091  1.4504                         0.068771  1.381629   95.258461
# r_0112  0.9555                         0.110775  0.844725   88.406591
# r_0300 -2.6656                        -0.472873  2.192727   82.260172
# r_0302  2.6656                         0.349689  2.315911   86.881406
# r_0366  7.6881                         2.851629  4.836471   62.908537
# r_0450  3.8563                         3.034005  0.822295   21.323429
# r_0452 -2.3128                        -0.174328  2.138472   92.462489
# r_0454  2.3128                        -0.000000  2.312800   100.000000
# r_0466  1.4504                         0.068771  1.381629   95.258461
# r_0467  2.9400                         3.515429  0.575429   19.572416
# r_0486  7.8302                         6.003360  1.826840   23.330690
# r_0534  4.9000                         4.900000  0.000000   0.000000
# r_0713  2.3128                         0.472873  1.839927   79.554097
# r_0718  0.7105                         0.000000  0.710500   100.000000
# r_0832  2.3128                         0.000004  2.312796   99.999839
# r_0886  3.8563                         3.034005  0.822295   21.323429
# r_0889  1.4504                         0.068771  1.381629   95.258461
# r_0892 -7.8302                        -6.003360  1.826840   23.330690
# r_0893 -7.6881                        -2.851629  4.836471   62.908537
# r_0958  1.3426                         0.986026  0.356574   26.558476
# r_0958  1.3426                         0.986026  0.356574   26.558476
# r_0959  4.0621                         0.084180  3.977920   97.927682
# r_0961  2.4255                         0.800824  1.624676   66.983133
# r_0962 -7.5068                        -2.606283  4.900517   65.281043
# r_1022 -2.3128                        -0.000000  2.312800   100.000000
# r_1048  0.4998                         0.000000  0.499800   100.000000
# r_1049 -0.4998                        -0.016430  0.483370   96.712606
# r_1050 -0.4165                         0.000000  0.416500   100.000000
# r_1054 -3.5819                        -3.045986  0.535914   14.961715
# r_1239  1.0633                         0.000000  1.063300   100.000000
# r_2034  2.0972                         1.336310  0.760890   36.281238
# r_2116  1.6758                         0.002131  1.673669   99.872828
# r_2131  2.6656                         0.349689  2.315911   86.881406
# r_4041  0.3000                         0.464143  0.164143   54.714414

# %% [markdown]
# <p style="float: center; font-size: 9pt; text-align: center; width: 80%;"><img src = "Results/Case 13/rf_pfba_exp_sim_plot.png", width = 100%></p>

# %% [markdown]
# ## Flux Variability Analysis (FVA) Simulation

# %%
rf_fva_res, rf_fva_exp_sim, _ = case13.simulationPipeline(rf_exp_df, cs = 'g_resp_fermentative', type = 'fva', res_exists = True, fname = 'Results/Case 13/res_fva_resp_fermentative_case13.sav')
pd.DataFrame(reactions).join(rf_fva_exp_sim, how = 'inner')
# Out:
#                                                                                                               Reaction  \
# r_0091  D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0112  Acetate <==> Acetyl-CoA
# r_0300  Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_0302  Citrate <==> Isocitrate
# r_0366  2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0450  D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452  (S)-Malate-mit <==> Fumarate
# r_0454  Succinate-mit <==> Fumarate
# r_0466  D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467  D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0486  D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0534  D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0713  (S)-Malate-mit <==> Oxaloacetate-mit
# r_0718  (S)-Malate-mit <==> Pyruvate + CO2
# r_0832  2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0886  D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0889  6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_0892  3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893  2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0958  Pyruvate + CO2 <==> Oxaloacetate
# r_0958  Pyruvate + CO2 <==> Oxaloacetate
# r_0959  Pyruvate <==> Acetaldehyde
# r_0961  Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_0962  Pyruvate <==> Phosphoenolpyruvate
# r_1022  Succinate-mit + CoA <==> Succinyl-CoA
# r_1048  Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1049  Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1050  D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_1054  D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_1239  Oxaloacetate <==> Oxaloacetate-mit
# r_2034  Pyruvate <==> Pyruvate-mit
# r_2116  Acetaldehyde <==> Acetate
# r_2131  Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_4041  Biomass
#
#         respiro-fermentative exp flux      maximum     minimum
# r_0091  1.4504                         0.074148     0.039750
# r_0112  0.9555                         0.114071     0.110774
# r_0300 -2.6656                        -0.477454    -0.472277
# r_0302  2.6656                         1000.000000 -999.527136
# r_0366  7.6881                         2.856118     2.849948
# r_0450  3.8563                         3.060127    -0.002293
# r_0452 -2.3128                        -0.177602    -0.170156
# r_0454  2.3128                        -18.963489   -0.000000
# r_0466  1.4504                         0.074148     0.039750
# r_0467  2.9400                         3.544463     3.510065
# r_0486  7.8302                         6.013072     6.001606
# r_0534  4.9000                         4.901668     4.899902
# r_0713  2.3128                         1000.000000  0.468698
# r_0718  0.7105                         0.011466     0.000000
# r_0832  2.3128                         0.004590     0.000000
# r_0886  3.8563                         3.060127     0.000000
# r_0889  1.4504                         0.074148     0.039750
# r_0892 -7.8302                        -6.013072    -6.001606
# r_0893 -7.6881                        -2.856118    -2.849948
# r_0958  1.3426                         1.031880     0.984997
# r_0958  1.3426                         1.031880     0.984997
# r_0959  4.0621                         0.086303     0.083222
# r_0961  2.4255                         0.805094     0.798621
# r_0962 -7.5068                        -2.610774    -2.604604
# r_1022 -2.3128                        -0.004586    -0.000000
# r_1048  0.4998                         0.018223    -3.053370
# r_1049 -0.4998                        -0.018223    -0.006757
# r_1050 -0.4165                        -0.104449    -0.115915
# r_1054 -3.5819                        -3.055678    -3.044212
# r_1239  1.0633                         0.004169     0.000000
# r_2034  2.0972                         1.340575     0.000000
# r_2116  1.6758                         0.005096     0.000000
# r_2131  2.6656                         0.361152     0.342042
# r_4041  0.3000                         0.464143     0.464139

# %% [markdown]
# # Fermentative growth

# %% [markdown]
# ## Flux Balance Analysis (FBA) Simulation

# %%
f_exp_df = case13.getColumnWithoutNAs(exp_dataset, 2, 'X')
# NO EtOH fluxes available for O2 flux estimation

f_fba_res, f_fba_exp_sim, f_fba_exp_sim_errors = case13.simulationPipeline(f_exp_df, cs = 'g_fermentative', type = 'fba', res_exists = True, fname = 'Results/Case 13/res_fba_fermentative_case13.sav')
pd.DataFrame(reactions).join(f_fba_exp_sim_errors, how = 'inner')
# Out:
#                                                                                                               Reaction  \
# r_0091  D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0112  Acetate <==> Acetyl-CoA
# r_0300  Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_0302  Citrate <==> Isocitrate
# r_0366  2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0450  D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452  (S)-Malate-mit <==> Fumarate
# r_0454  Succinate-mit <==> Fumarate
# r_0466  D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467  D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0486  D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0534  D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0713  (S)-Malate-mit <==> Oxaloacetate-mit
# r_0718  (S)-Malate-mit <==> Pyruvate + CO2
# r_0832  2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0886  D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0889  6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_0892  3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893  2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0958  Pyruvate + CO2 <==> Oxaloacetate
# r_0958  Pyruvate + CO2 <==> Oxaloacetate
# r_0959  Pyruvate <==> Acetaldehyde
# r_0961  Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_0962  Pyruvate <==> Phosphoenolpyruvate
# r_1022  Succinate-mit + CoA <==> Succinyl-CoA
# r_1048  Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1049  Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1050  D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_1054  D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_1239  Oxaloacetate <==> Oxaloacetate-mit
# r_2034  Pyruvate <==> Pyruvate-mit
# r_2116  Acetaldehyde <==> Acetate
# r_2131  Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_4041  Biomass
#
#         fermentative exp flux    Sim Flux    Abs Error     Rel Error
# r_0091  1.2427                 0.113184    1.129516     90.892116
# r_0112  0.9135                 0.186462    0.727038     79.588230
# r_0300 -1.8847                -0.794241    1.090459     57.858475
# r_0302  1.8847                -999.205759  1001.090459  53116.700731
# r_0366  13.7770                4.789505    8.987495     65.235500
# r_0450  7.1683                 5.124230    2.044070     28.515412
# r_0452 -1.3826                -0.292802    1.089798     78.822358
# r_0454  1.3826                -0.000000    1.382600     100.000000
# r_0466  1.2427                 0.113184    1.129516     90.892116
# r_0467  6.4112                 5.906788    0.504412     7.867672
# r_0486  14.0733                10.083906   3.989394     28.347251
# r_0534  8.2300                 8.230000    0.000000     0.000000
# r_0713  1.3826                 0.794241    0.588359     42.554512
# r_0718  1.7201                 0.000000    1.720100     100.000000
# r_0832  1.3826                 0.000006    1.382594     99.999549
# r_0886  7.1683                 5.124230    2.044070     28.515412
# r_0889  1.2427                 0.113184    1.129516     90.892116
# r_0892 -14.0733               -10.083906   3.989394     28.347251
# r_0893 -13.7770               -4.789505    8.987495     65.235500
# r_0958  2.5842                 1.656138    0.928062     35.912947
# r_0958  2.5842                 1.656138    0.928062     35.912947
# r_0959  10.1641                0.141792    10.022308    98.604976
# r_0961  1.9505                 1.344553    0.605947     31.066232
# r_0962 -13.5466               -4.377420    9.169180     67.686211
# r_1022 -1.3826                -0.000000    1.382600     100.000000
# r_1048  0.4362                 0.026822    0.409378     93.851081
# r_1049 -0.4362                -0.026822    0.409378     93.851081
# r_1050 -0.3127                -0.179221    0.133479     42.685914
# r_1054 -6.6252                -5.116758    1.508442     22.768253
# r_1239  2.2303                 0.000000    2.230300     100.000000
# r_2034  0.7983                 0.000000    0.798300     100.000000
# r_2116  1.3250                 0.000000    1.325000     100.000000
# r_2131  1.8847                 0.587341    1.297359     68.836364
# r_4041  0.4000                 0.779579    0.379579     94.894749

# %% [markdown]
# <p style="float: center; font-size: 9pt; text-align: center; width: 80%;"><img src = "Results/Case 13/f_fba_exp_sim_plot.png", width = 100%></p>

# %% [markdown]
# ## Parsimonious Flux Balance Analysis (pFBA) Simulation

# %%
f_pfba_res, f_pfba_exp_sim, f_pfba_exp_sim_errors = case13.simulationPipeline(f_exp_df, cs = 'g_fermentative',type = 'pfba', res_exists = True, fname = 'Results/Case 13/res_pfba_fermentative_case13.sav')
pd.DataFrame(reactions).join(f_pfba_exp_sim_errors, how = 'inner')
# Out:
#                                                                                                               Reaction  \
# r_0091  D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0112  Acetate <==> Acetyl-CoA
# r_0300  Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_0302  Citrate <==> Isocitrate
# r_0366  2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0450  D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452  (S)-Malate-mit <==> Fumarate
# r_0454  Succinate-mit <==> Fumarate
# r_0466  D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467  D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0486  D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0534  D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0713  (S)-Malate-mit <==> Oxaloacetate-mit
# r_0718  (S)-Malate-mit <==> Pyruvate + CO2
# r_0832  2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0886  D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0889  6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_0892  3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893  2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0958  Pyruvate + CO2 <==> Oxaloacetate
# r_0958  Pyruvate + CO2 <==> Oxaloacetate
# r_0959  Pyruvate <==> Acetaldehyde
# r_0961  Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_0962  Pyruvate <==> Phosphoenolpyruvate
# r_1022  Succinate-mit + CoA <==> Succinyl-CoA
# r_1048  Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1049  Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1050  D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_1054  D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_1239  Oxaloacetate <==> Oxaloacetate-mit
# r_2034  Pyruvate <==> Pyruvate-mit
# r_2116  Acetaldehyde <==> Acetate
# r_2131  Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_4041  Biomass
#
#         fermentative exp flux   Sim Flux  Abs Error   Rel Error
# r_0091  1.2427                 0.115508   1.127192   90.705103
# r_0112  0.9135                 0.186057   0.727443   79.632531
# r_0300 -1.8847                -0.794233   1.090467   57.858897
# r_0302  1.8847                 0.587335   1.297365   68.836675
# r_0366  13.7770                4.789572   8.987428   65.235012
# r_0450  7.1683                 5.095889   2.072411   28.910769
# r_0452 -1.3826                -0.292799   1.089801   78.822570
# r_0454  1.3826                -0.000000   1.382600   100.000000
# r_0466  1.2427                 0.115508   1.127192   90.705103
# r_0467  6.4112                 5.904486   0.506714   7.903576
# r_0486  14.0733                10.083195  3.990105   28.352305
# r_0534  8.2300                 8.230000   0.000000   0.000000
# r_0713  1.3826                 0.794233   0.588367   42.555086
# r_0718  1.7201                 0.000000   1.720100   100.000000
# r_0832  1.3826                 0.000006   1.382594   99.999549
# r_0886  7.1683                 5.095889   2.072411   28.910769
# r_0889  1.2427                 0.115508   1.127192   90.705103
# r_0892 -14.0733               -10.083195  3.990105   28.352305
# r_0893 -13.7770               -4.789572   8.987428   65.235012
# r_0958  2.5842                 1.656121   0.928079   35.913588
# r_0958  2.5842                 1.656121   0.928079   35.913588
# r_0959  10.1641                0.141387   10.022713  98.608953
# r_0961  1.9505                 1.345058   0.605442   31.040368
# r_0962 -13.5466               -4.377491   9.169109   67.685685
# r_1022 -1.3826                -0.000000   1.382600   100.000000
# r_1048  0.4362                 0.000000   0.436200   100.000000
# r_1049 -0.4362                -0.027596   0.408604   93.673462
# r_1050 -0.3127                 0.000000   0.312700   100.000000
# r_1054 -6.6252                -5.116014   1.509186   22.779481
# r_1239  2.2303                 0.000000   2.230300   100.000000
# r_2034  0.7983                 2.244455   1.446155   181.154347
# r_2116  1.3250                 0.003579   1.321421   99.729853
# r_2131  1.8847                 0.587335   1.297365   68.836675
# r_4041  0.4000                 0.779571   0.379571   94.892800

# %% [markdown]
# <p style="float: center; font-size: 9pt; text-align: center; width: 80%;"><img src = "Results/Case 13/f_pfba_exp_sim_plot.png", width = 100%></p>

# %% [markdown]
# ## Flux Variability Analysis (FVA) Simulation

# %%
f_fva_res, f_fva_exp_sim, _ = case13.simulationPipeline(f_exp_df, cs = 'g_fermentative', type = 'fva', res_exists = True, fname = 'Results/Case 13/res_fva_fermentative_case13.sav')
pd.DataFrame(reactions).join(f_fva_exp_sim, how = 'inner')
# Out:
#                                                                                                               Reaction  \
# r_0091  D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0112  Acetate <==> Acetyl-CoA
# r_0300  Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_0302  Citrate <==> Isocitrate
# r_0366  2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0450  D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452  (S)-Malate-mit <==> Fumarate
# r_0454  Succinate-mit <==> Fumarate
# r_0466  D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467  D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0486  D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0534  D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0713  (S)-Malate-mit <==> Oxaloacetate-mit
# r_0718  (S)-Malate-mit <==> Pyruvate + CO2
# r_0832  2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0886  D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0889  6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_0892  3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893  2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0958  Pyruvate + CO2 <==> Oxaloacetate
# r_0958  Pyruvate + CO2 <==> Oxaloacetate
# r_0959  Pyruvate <==> Acetaldehyde
# r_0961  Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_0962  Pyruvate <==> Phosphoenolpyruvate
# r_1022  Succinate-mit + CoA <==> Succinyl-CoA
# r_1048  Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1049  Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1050  D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_1054  D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_1239  Oxaloacetate <==> Oxaloacetate-mit
# r_2034  Pyruvate <==> Pyruvate-mit
# r_2116  Acetaldehyde <==> Acetate
# r_2131  Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_4041  Biomass
#
#         fermentative exp flux      maximum     minimum
# r_0091  1.2427                 0.124539     0.066764
# r_0112  0.9135                 0.191593     0.186055
# r_0300 -1.8847                -0.801929    -0.793233
# r_0302  1.8847                 1000.000000 -999.205781
# r_0366  13.7770                4.797113     4.786749
# r_0450  7.1683                 5.139764    -0.003852
# r_0452 -1.3826                -0.298299    -0.285793
# r_0454  1.3826                -31.850921   -0.000000
# r_0466  1.2427                 0.124539     0.066764
# r_0467  6.4112                 5.953251     5.895477
# r_0486  14.0733                10.099506    10.080248
# r_0534  8.2300                 8.232801     8.229835
# r_0713  1.3826                 1000.000000  0.787222
# r_0718  1.7201                 0.019258     0.000000
# r_0832  1.3826                 0.007709     0.000000
# r_0886  7.1683                 5.139764     0.000000
# r_0889  1.2427                 0.124539     0.066764
# r_0892 -14.0733               -10.099506   -10.080248
# r_0893 -13.7770               -4.797113    -4.786749
# r_0958  2.5842                 1.733137     1.654393
# r_0958  2.5842                 1.733137     1.654393
# r_0959  10.1641                0.144955     0.139778
# r_0961  1.9505                 1.352229     1.341357
# r_0962 -13.5466               -4.385035    -4.374672
# r_1022 -1.3826                -0.007703    -0.000000
# r_1048  0.4362                 0.030607    -5.128415
# r_1049 -0.4362                -0.030607    -0.011349
# r_1050 -0.3127                -0.175432    -0.194690
# r_1054 -6.6252                -5.132292    -5.113034
# r_1239  2.2303                 0.007003     0.000000
# r_2034  0.7983                 2.251618     0.000000
# r_2116  1.3250                 0.008559     0.000000
# r_2131  1.8847                 0.606587     0.574491
# r_4041  0.4000                 0.779571     0.779563
