# %% [markdown]
# # Case 9 Report (Gombert et al, 2001)
# This report contains the results with case 9 simulations.
# Paper: [*Network Identification and Flux Quantification in the Central Metabolism of Saccharomyces cerevisiae under Different Conditions of Glucose Repression*](http://jb.asm.org/content/183/4/1441.long)
# **Abstract**
# The network structure and the metabolic fluxes in central carbon metabolism were characterized in aerobically
# grown cells of Saccharomyces cerevisiae. The cells were grown under both high and low glucose concentrations,
# i.e., either in a chemostat at steady state with a specific growth rate of 0.1 h ⴚ1 or in a batch culture with
# a specific growth rate of 0.37 h ⴚ1 . Experiments were carried out using [1- 13 C]glucose as the limiting substrate,
# and the resulting summed fractional labelings of intracellular metabolites were measured by gas chromatography
# coupled to mass spectrometry. The data were used as inputs to a flux estimation routine that involved
# appropriate mathematical modelling of the central carbon metabolism of S. cerevisiae. The results showed that
# the analysis is very robust, and it was possible to quantify the fluxes in the central carbon metabolism under
# both growth conditions. In the batch culture, 16.2 of every 100 molecules of glucose consumed by the cells entered
# the pentose-phosphate pathway, whereas the same relative flux was 44.2 per 100 molecules in the chemostat.
# The tricarboxylic acid cycle does not operate as a cycle in batch-growing cells, in contrast to the
# chemostat condition. Quantitative evidence was also found for threonine aldolase and malic enzyme activities,
# in accordance with published data. Disruption of the MIG1 gene did not cause changes in the metabolic network
# structure or in the flux pattern.
# **NOTES**
# - Wild-Type S.Cerevisiae CEN.PK 113-7D (MATa MAL2-8c SUC2) used in this study is very similar to that used to build the model (S288C)
# - O2 flux estimation not possible (ethanol flux of 0 independently of O2 flux)
# <p style="float: center; font-size: 9pt; text-align: center; width: 100%;"><img src = "Results/Case 9/gombert_2001_fig2", width = 80%></p>

# %%
import warnings
from case_9 import *
pd.set_option('display.max_colwidth', -1)
warnings.filterwarnings('ignore')
#Initialization
case9 = Case9()
case9.model = case9.loadObjectFromFile('model_yeast_76.sav')
case9.model.solver = 'optlang-cplex'
case9.setMedium('MINIMAL')
case9.dictsForCase9()

# %% [markdown]
# ## General datasets

# %%
#General datasets
exp_dataset, reactions = case9.loadExperimentalRes('Results/Case 9/case9_experimental_fluxes.csv')
pd.DataFrame(reactions)
# Out:
#                                                                                                                  Reaction
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0961     Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0959     Pyruvate <==> Acetaldehyde
# r_0163     Ethanol <==> Acetaldehyde
# r_2116     Acetaldehyde <==> Acetate
# r_0112     Acetate <==> Acetyl-CoA
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0718     (S)-Malate-mit <==> Pyruvate + CO2
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass

# %% [markdown]
# # Batch culture

# %% [markdown]
# Brief summary of the results shown below:
# - Glycolysis simulated fluxes are lower than those in experimental data (72% of the D-Glucose-6-phosphate is converted into D-Fructose-6-phosphate; 27% is converted into D-Glucose-1-phosphate);
# - Pentose phosphate pathway activity reduced in simulated fluxes (only 1% of D-Glucose-6-phosphate is converted into 6-phosphono-D-glucono-1,5-lactone);
# - TCA cycle activity is higher in simulated fluxes. This could be due to the fact that experimentally there is a considerable production of ethanol, whereas simulated fluxes show that
# only 3% of produced piruvate is used for fermentative purposes;
# - FVA shows most reactions are fixed, except:
#     - r_0713 	(S)-Malate-mit <==> Oxaloacetate-mit
#     - r_0454 	Succinate-mit <==> Fumarate
#     - r_0302 	Citrate <==> Isocitrate
#     - r_0450 	D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
#     - r_1048 	Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
#     - r_0886 	D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
#     - r_0163 	Ethanol <==> Acetaldehyde

# %% [markdown]
# ## Flux Balance Analysis (FBA) Simulation

# %%
b_exp_df = case9.getColumnWithoutNAs(exp_dataset, 0, 'X')
# O2 flux estimation not possible (ethanol flux of 0 independently of O2 flux)
b_fba_res, b_fba_exp_sim, b_fba_exp_sim_errors = case9.simulationPipeline(b_exp_df, cs = 'glucose', type = 'fba', res_exists = True, fname = 'Results/Case 9/res_fba_batch_case9.sav')
pd.concat([reactions, b_fba_exp_sim_errors], axis = 1, join = 'inner')
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0961     Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0959     Pyruvate <==> Acetaldehyde
# r_0163     Ethanol <==> Acetaldehyde
# r_2116     Acetaldehyde <==> Acetate
# r_0112     Acetate <==> Acetyl-CoA
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0718     (S)-Malate-mit <==> Pyruvate + CO2
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            batch exp flux   Sim Flux  Abs Error     Rel Error
# Yeast7_ID
# r_0534     15.9000         15.900000  0.000000   0.000000e+00
# r_0962    -28.3974        -8.456983   19.940417  7.021916e+01
# r_0961     0.0159          2.597618   2.581718   1.623722e+04
# r_2131     0.3975          1.134717   0.737217   1.854635e+02
# r_0713     0.0000          1.534439   1.534439   inf
# r_0300    -0.3975         -1.534439   1.136939   2.860225e+02
# r_1022     0.0000         -0.000000   0.000000  NaN
# r_0454     0.0000         -0.000000   0.000000  NaN
# r_1054    -14.4690        -9.885352   4.583648   3.167909e+01
# r_0486     28.6041         19.481666  9.122434   3.189205e+01
# r_0450     14.4690         9.899788   4.569212   3.157932e+01
# r_0452     0.0000         -0.565681   0.565681   inf
# r_0302     0.3975          0.000000   0.397500   1.000000e+02
# r_0892    -28.6041        -19.481666  9.122434   3.189205e+01
# r_0893    -28.6041        -9.253115   19.350985  6.765109e+01
# r_0889     2.5758          0.218666   2.357134   9.151076e+01
# r_1049    -0.7473         -0.051818   0.695482   9.306595e+01
# r_1048     1.5900          0.051818   1.538182   9.674100e+01
# r_1050    -1.5900         -0.346247   1.243753   7.822343e+01
# r_0466     2.5758          0.218666   2.357134   9.151076e+01
# r_0467     12.8790         11.411656  1.467344   1.139331e+01
# r_0886     14.4690         9.899788   4.569212   3.157932e+01
# r_0959     26.9187         0.273935   26.644765  9.898236e+01
# r_0163     25.2333         0.000000   25.233300  1.000000e+02
# r_2116     1.6854          0.000000   1.685400   1.000000e+02
# r_0112     1.1607          0.360235   0.800465   6.896394e+01
# r_0958     1.4151          3.199585   1.784485   1.261031e+02
# r_0366     28.6041         9.253115   19.350985  6.765109e+01
# r_0832     0.0000          0.000012   0.000012   inf
# r_0091     2.5758          0.218666   2.357134   9.151076e+01
# r_0718     0.6360          0.000000   0.636000   1.000000e+02
# r_1239     1.3515          0.000000   1.351500   1.000000e+02
# r_4041     0.3700          1.506113   1.136113   3.070574e+02

# %% [markdown]
# <p style="float: center; font-size: 9pt; text-align: center; width: 80%;"><img src = "Results/Case 9/b_fba_exp_sim_plot.png", width = 100%></p>

# %% [markdown]
# ## Parsimonious Flux Balance Analysis (pFBA) Simulation

# %%
b_pfba_res, b_pfba_exp_sim, b_pfba_exp_sim_errors = case9.simulationPipeline(b_exp_df, cs = 'glucose',type = 'pfba', res_exists = True, fname = 'Results/Case 9/res_pfba_batch_case9.sav')
pd.concat([reactions, b_pfba_exp_sim_errors], axis = 1, join = 'inner')
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0961     Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0959     Pyruvate <==> Acetaldehyde
# r_0163     Ethanol <==> Acetaldehyde
# r_2116     Acetaldehyde <==> Acetate
# r_0112     Acetate <==> Acetyl-CoA
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0718     (S)-Malate-mit <==> Pyruvate + CO2
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            batch exp flux   Sim Flux  Abs Error     Rel Error
# Yeast7_ID
# r_0534     15.9000         15.900000  0.000000   0.000000e+00
# r_0962    -28.3974        -8.457121   19.940279  7.021868e+01
# r_0961     0.0159          2.598592   2.582692   1.624335e+04
# r_2131     0.3975          1.134706   0.737206   1.854606e+02
# r_0713     0.0000          1.534424   1.534424   inf
# r_0300    -0.3975         -1.534424   1.136924   2.860187e+02
# r_1022     0.0000         -0.000000   0.000000  NaN
# r_0454     0.0000         -0.000000   0.000000  NaN
# r_1054    -14.4690        -9.883915   4.585085   3.168903e+01
# r_0486     28.6041         19.480292  9.123808   3.189685e+01
# r_0450     14.4690         9.845035   4.623965   3.195774e+01
# r_0452     0.0000         -0.565675   0.565675   inf
# r_0302     0.3975          1.134706   0.737206   1.854606e+02
# r_0892    -28.6041        -19.480292  9.123808   3.189685e+01
# r_0893    -28.6041        -9.253244   19.350856  6.765064e+01
# r_0889     2.5758          0.223156   2.352644   9.133645e+01
# r_1049    -0.7473         -0.053315   0.693985   9.286566e+01
# r_1048     1.5900          0.000000   1.590000   1.000000e+02
# r_1050    -1.5900         -0.344747   1.245253   7.831782e+01
# r_0466     2.5758          0.223156   2.352644   9.133645e+01
# r_0467     12.8790         11.407209  1.471791   1.142784e+01
# r_0886     14.4690         9.845035   4.623965   3.195774e+01
# r_0959     26.9187         0.273154   26.645546  9.898526e+01
# r_0163     25.2333         0.000000   25.233300  1.000000e+02
# r_2116     1.6854          0.006915   1.678485   9.958969e+01
# r_0112     1.1607          0.359454   0.801246   6.903130e+01
# r_0958     1.4151          3.199553   1.784453   1.261009e+02
# r_0366     28.6041         9.253244   19.350856  6.765064e+01
# r_0832     0.0000          0.000012   0.000012   inf
# r_0091     2.5758          0.223156   2.352644   9.133645e+01
# r_0718     0.6360          0.000000   0.636000   1.000000e+02
# r_1239     1.3515          0.000000   1.351500   1.000000e+02
# r_4041     0.3700          1.506097   1.136097   3.070534e+02

# %% [markdown]
# <p style="float: center; font-size: 9pt; text-align: center; width: 80%;"><img src = "Results/Case 9/b_pfba_exp_sim_plot.png", width = 100%></p>

# %% [markdown]
# ## Flux Variability Analysis (FVA) Simulation

# %%
b_fva_res, b_fva_exp_sim, _ = case9.simulationPipeline(b_exp_df, cs = 'glucose', type = 'fva', res_exists = True, fname = 'Results/Case 9/res_fva_batch_case9.sav')
pd.concat([reactions, b_fva_exp_sim], axis = 1, join = 'inner')
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0961     Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0959     Pyruvate <==> Acetaldehyde
# r_0163     Ethanol <==> Acetaldehyde
# r_2116     Acetaldehyde <==> Acetate
# r_0112     Acetate <==> Acetyl-CoA
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0718     (S)-Malate-mit <==> Pyruvate + CO2
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            batch exp flux      maximum     minimum
# Yeast7_ID
# r_0534     15.9000         15.902706    15.899841
# r_0962    -28.3974        -8.464340    -8.454325
# r_0961     0.0159          2.605033     2.594527
# r_2131     0.3975          1.153309     1.122304
# r_0713     0.0000          1000.000000  1.527658
# r_0300    -0.3975         -1.541865    -1.533431
# r_1022     0.0000         -0.007441    -0.000000
# r_0454     0.0000         -61.533294   -0.000000
# r_1054    -14.4690        -9.900358    -9.881755
# r_0486     28.6041         19.496735    19.478132
# r_0450     14.4690         9.914794    -0.003721
# r_0452     0.0000         -0.570990    -0.558910
# r_0302     0.3975          1000.000000 -998.465588
# r_0892    -28.6041        -19.496735   -19.478132
# r_0893    -28.6041        -9.260463    -9.250448
# r_0889     2.5758          0.229635     0.173826
# r_1049    -0.7473         -0.055475    -0.036872
# r_1048     1.5900          0.055475    -9.877922
# r_1050    -1.5900         -0.342587    -0.361190
# r_0466     2.5758          0.229635     0.173826
# r_0467     12.8790         11.456539    11.400730
# r_0886     14.4690         9.914794     0.000000
# r_0959     26.9187         0.276991     0.271740
# r_0163     25.2333         1000.000000  0.000000
# r_2116     1.6854          0.008268     0.000000
# r_0112     1.1607          0.365193     0.359454
# r_0958     1.4151          3.273965     3.197900
# r_0366     28.6041         9.260463     9.250448
# r_0832     0.0000          0.007453     0.000000
# r_0091     2.5758          0.229635     0.173826
# r_0718     0.6360          0.018603     0.000000
# r_1239     1.3515          0.006765     0.000000
# r_4041     0.3700          1.506097     1.506097

# %% [markdown]
# # Chemostat culture

# %% [markdown]
# Brief summary of the results shown below:
# - Overall, glycolysis simulated fluxes are similar to those in experimental data (72% of the D-Glucose-6-phosphate is converted into D-Fructose-6-phosphate; 27% is converted into D-Glucose-1-phosphate);
# - Pentose phosphate pathway activity reduced in simulated fluxes (only 1% of D-Glucose-6-phosphate is converted into 6-phosphono-D-glucono-1,5-lactone);
# - TCA cycle activity is lower in simulated fluxes. This could be due to the fact that only about 51% of the produced pyruvate enters the mitochondrion and from this only 57% is converted into Acetyl-CoA
# (37% is converted into 2-acetyllactic acid);
# - Although produced in low amounts, simulated fluxes show that acetate is being produced as observed experimentally;
# - FVA shows most reactions are fixed, except:
#     - r_0713 	(S)-Malate-mit <==> Oxaloacetate-mit
#     - r_0454 	Succinate-mit <==> Fumarate
#     - r_0302 	Citrate <==> Isocitrate
#     - r_0450 	D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
#     - r_1048 	Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
#     - r_0886 	D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
#     - r_0163 	Ethanol <==> Acetaldehyde

# %% [markdown]
# ## Flux Balance Analysis (FBA) Simulation

# %%
c_exp_df = case9.getColumnWithoutNAs(exp_dataset, 1, 'X')
# O2 flux estimation not possible (ethanol flux of 0 independently of O2 flux)
c_fba_res, c_fba_exp_sim, c_fba_exp_sim_errors = case9.simulationPipeline(c_exp_df, cs = 'glucose', type = 'fba', res_exists = True, fname = 'Results/Case 9/res_fba_chemostat_case9.sav')
pd.concat([reactions, c_fba_exp_sim_errors], axis = 1, join = 'inner') #Plot not showing r_0302
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0961     Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0959     Pyruvate <==> Acetaldehyde
# r_0163     Ethanol <==> Acetaldehyde
# r_2116     Acetaldehyde <==> Acetate
# r_0112     Acetate <==> Acetyl-CoA
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0718     (S)-Malate-mit <==> Pyruvate + CO2
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            chemostat exp flux      Sim Flux    Abs Error     Rel Error
# Yeast7_ID
# r_0534     1.1700              1.170000e+00  0.000000     0.000000e+00
# r_0962    -1.4286             -6.223063e-01  0.806294     5.643943e+01
# r_0961     0.4668              1.911455e-01  0.275655     5.905196e+01
# r_2131     0.7008              8.349806e-02  0.617302     8.808532e+01
# r_0713    -0.5745              1.129116e-01  0.687412     1.196539e+02
# r_0300    -0.7008             -1.129116e-01  0.587888     8.388819e+01
# r_1022    -0.5745             -0.000000e+00  0.574500     1.000000e+02
# r_0454     0.5745             -4.527826e+00  5.102326     8.881333e+02
# r_1054    -0.7055             -7.274127e-01  0.021913     3.105981e+00
# r_0486     1.4871              1.433557e+00  0.053543     3.600529e+00
# r_0450     0.7055              7.284749e-01  0.022975     3.256546e+00
# r_0452    -0.5745             -4.162557e-02  0.532874     9.275447e+01
# r_0302     0.7008              1.000000e+03  999.299200   1.425941e+05
# r_0892    -1.4871             -1.433557e+00  0.053543     3.600529e+00
# r_0893    -1.4871             -6.808896e-01  0.806210     5.421360e+01
# r_0889     0.5171              1.609052e-02  0.501009     9.688832e+01
# r_1049    -0.1416             -3.813034e-03  0.137787     9.730718e+01
# r_1048     0.3124              3.813034e-03  0.308587     9.877944e+01
# r_1050    -0.3124             -2.547858e-02  0.286921     9.184424e+01
# r_0466     0.5171              1.609052e-02  0.501009     9.688832e+01
# r_0467     0.3931              8.397256e-01  0.446626     1.136163e+02
# r_0886     0.7055              7.284749e-01  0.022975     3.256546e+00
# r_0959     0.5277              2.015750e-02  0.507543     9.618012e+01
# r_0163     0.0000              1.000000e+03  1000.000000  inf
# r_2116     0.5359              0.000000e+00  0.535900     1.000000e+02
# r_0112     0.5347              2.650789e-02  0.508192     9.504247e+01
# r_0958     0.3194              2.354412e-01  0.083959     2.628641e+01
# r_0366     1.4871              6.808896e-01  0.806210     5.421360e+01
# r_0832     0.5745              8.866172e-07  0.574499     9.999985e+01
# r_0091     0.5171              1.609052e-02  0.501009     9.688832e+01
# r_0718     0.0784              0.000000e+00  0.078400     1.000000e+02
# r_1239     1.8568              0.000000e+00  1.856800     1.000000e+02
# r_4041     0.1000              1.108271e-01  0.010827     1.082715e+01

# %% [markdown]
# <p style="float: center; font-size: 9pt; text-align: center; width: 80%;"><img src = "Results/Case 9/c_fba_exp_sim_plot.png", width = 100%></p>

# %% [markdown]
# ## Parsimonious Flux Balance Analysis (pFBA) Simulation

# %%
c_pfba_res, c_pfba_exp_sim, c_pfba_exp_sim_errors = case9.simulationPipeline(c_exp_df, cs = 'glucose',type = 'pfba', res_exists = True, fname = 'Results/Case 9/res_pfba_chemostat_case9.sav')
pd.concat([reactions, c_pfba_exp_sim_errors], axis = 1, join = 'inner')
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0961     Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0959     Pyruvate <==> Acetaldehyde
# r_0163     Ethanol <==> Acetaldehyde
# r_2116     Acetaldehyde <==> Acetate
# r_0112     Acetate <==> Acetyl-CoA
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0718     (S)-Malate-mit <==> Pyruvate + CO2
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            chemostat exp flux      Sim Flux  Abs Error   Rel Error
# Yeast7_ID
# r_0534     1.1700              1.170000e+00  0.000000   0.000000
# r_0962    -1.4286             -6.223165e-01  0.806284   56.438718
# r_0961     0.4668              1.912172e-01  0.275583   59.036593
# r_2131     0.7008              8.349723e-02  0.617303   88.085442
# r_0713    -0.5745              1.129105e-01  0.687410   119.653691
# r_0300    -0.7008             -1.129105e-01  0.587890   83.888348
# r_1022    -0.5745             -0.000000e+00  0.574500   100.000000
# r_0454     0.5745             -0.000000e+00  0.574500   100.000000
# r_1054    -0.7055             -7.273069e-01  0.021807   3.090991
# r_0486     1.4871              1.433455e+00  0.053645   3.607328
# r_0450     0.7055              7.244460e-01  0.018946   2.685470
# r_0452    -0.5745             -4.162515e-02  0.532875   92.754543
# r_0302     0.7008              8.349723e-02  0.617303   88.085442
# r_0892    -1.4871             -1.433455e+00  0.053645   3.607328
# r_0893    -1.4871             -6.808991e-01  0.806201   54.212957
# r_0889     0.5171              1.642090e-02  0.500679   96.824424
# r_1049    -0.1416             -3.923178e-03  0.137677   97.229394
# r_1048     0.3124              0.000000e+00  0.312400   100.000000
# r_1050    -0.3124             -2.536814e-02  0.287032   91.879595
# r_0466     0.5171              1.642090e-02  0.500679   96.824424
# r_0467     0.3931              8.393984e-01  0.446298   113.533034
# r_0886     0.7055              7.244460e-01  0.018946   2.685470
# r_0959     0.5277              2.010003e-02  0.507600   96.191012
# r_0163     0.0000              0.000000e+00  0.000000  NaN
# r_2116     0.5359              5.088649e-04  0.535391   99.905045
# r_0112     0.5347              2.645036e-02  0.508250   95.053233
# r_0958     0.3194              2.354388e-01  0.083961   26.287151
# r_0366     1.4871              6.808991e-01  0.806201   54.212957
# r_0832     0.5745              8.866083e-07  0.574499   99.999846
# r_0091     0.5171              1.642090e-02  0.500679   96.824424
# r_0718     0.0784              0.000000e+00  0.078400   100.000000
# r_1239     1.8568              0.000000e+00  1.856800   100.000000
# r_4041     0.1000              1.108260e-01  0.010826   10.826040

# %% [markdown]
# <p style="float: center; font-size: 9pt; text-align: center; width: 80%;"><img src = "Results/Case 9/c_pfba_exp_sim_plot.png", width = 100%></p>

# %% [markdown]
# ## Flux Variability Analysis (FVA) Simulation

# %%
c_fva_res, c_fva_exp_sim, _ = case9.simulationPipeline(c_exp_df, cs = 'glucose', type = 'fva', res_exists = True, fname = 'Results/Case 9/res_fva_chemostat_case9.sav')
pd.concat([reactions, c_fva_exp_sim], axis = 1, join = 'inner')
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0961     Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0959     Pyruvate <==> Acetaldehyde
# r_0163     Ethanol <==> Acetaldehyde
# r_2116     Acetaldehyde <==> Acetate
# r_0112     Acetate <==> Acetyl-CoA
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0718     (S)-Malate-mit <==> Pyruvate + CO2
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            chemostat exp flux      maximum     minimum
# Yeast7_ID
# r_0534     1.1700              1.170199     1.169988
# r_0962    -1.4286             -0.622847    -0.622111
# r_0961     0.4668              0.191691     0.190918
# r_2131     0.7008              0.084866     0.082585
# r_0713    -0.5745              1000.000000  0.112413
# r_0300    -0.7008             -0.113458    -0.112837
# r_1022    -0.5745             -0.000547    -0.000000
# r_0454     0.5745             -4.527922    -0.000000
# r_1054    -0.7055             -0.728516    -0.727148
# r_0486     1.4871              1.434665     1.433297
# r_0450     0.7055              0.729579    -0.000274
# r_0452    -0.5745             -0.042016    -0.041095
# r_0302     0.7008              1000.000000 -999.887090
# r_0892    -1.4871             -1.434665    -1.433279
# r_0893    -1.4871             -0.681430    -0.680693
# r_0889     0.5171              0.016897     0.012576
# r_1049    -0.1416             -0.004082    -0.002714
# r_1048     0.3124              0.004082    -0.726865
# r_1050    -0.3124             -0.025209    -0.026578
# r_0466     0.5171              0.016897     0.012576
# r_0467     0.3931              0.843027     0.838870
# r_0886     0.7055              0.729579     0.000000
# r_0959     0.5277              0.020382     0.019988
# r_0163     0.0000              1000.000000  0.000000
# r_2116     0.5359              0.000608     0.000000
# r_0112     0.5347              0.026873     0.026450
# r_0958     0.3194              0.240912     0.235309
# r_0366     1.4871              0.681430     0.680693
# r_0832     0.5745              0.000548     0.000000
# r_0091     0.5171              0.016897     0.012791
# r_0718     0.0784              0.001368     0.000000
# r_1239     1.8568              0.000498     0.000000
# r_4041     0.1000              0.110826     0.110826
