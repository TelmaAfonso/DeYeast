# %% [markdown]
# # Case 9 Report
# This report contains the results with case 9 simulations.

# %%
import warnings
from case_9 import *

pd.set_option('display.max_colwidth', -1)
warnings.filterwarnings('ignore')

#Initialization
case9 = Case9()
case9.model = case9.loadObjectFromFile('model_yeast_76.sav')
case9.model.solver = 'optlang-cplex'
case9.setMedium('MINIMAL')
case9.dictsForCase9()

# %% [markdown]
# ## General datasets

# %%
#General datasets
exp_dataset, reactions = case9.loadExperimentalRes('Results/Case 9/case9_experimental_fluxes.csv')
pd.DataFrame(reactions)
# Out:
#                                                                                                                  Reaction
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0961     Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0959     Pyruvate <==> Acetaldehyde
# r_0163     Ethanol <==> Acetaldehyde
# r_2116     Acetaldehyde <==> Acetate
# r_0112     Acetate <==> Acetyl-CoA
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0718     (S)-Malate-mit <==> Pyruvate + CO2
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass

# %% [markdown]
# # Batch culture

# %% [markdown]
# ## Flux Balance Analysis (FBA) Simulation

# %%
b_exp_df = case9.getColumnWithoutNAs(exp_dataset, 0, 'X')
# O2 flux estimation not possible (ethanol flux of 0 independently of O2 flux)

b_fba_res, b_fba_exp_sim, b_fba_exp_sim_errors = case9.simulationPipeline(b_exp_df, cs = 'glucose', type = 'fba', res_exists = True, fname = 'Results/Case 9/res_fba_batch_case9.sav')
pd.concat([reactions, b_fba_exp_sim_errors], axis = 1, join = 'inner')
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0961     Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0959     Pyruvate <==> Acetaldehyde
# r_0163     Ethanol <==> Acetaldehyde
# r_2116     Acetaldehyde <==> Acetate
# r_0112     Acetate <==> Acetyl-CoA
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0718     (S)-Malate-mit <==> Pyruvate + CO2
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            batch exp flux    Sim Flux   Abs Error     Rel Error
# Yeast7_ID
# r_0534     1.5000          1.500000    0.000000    0.000000e+00
# r_0962    -2.6790         -0.797829    1.881171    7.021916e+01
# r_0961     0.0015          0.245058    0.243558    1.623722e+04
# r_2131     0.0375          0.107049    0.069549    1.854635e+02
# r_0713     0.0000          0.144758    0.144758    inf
# r_0300    -0.0375         -0.144758    0.107258    2.860225e+02
# r_1022     0.0000         -0.000000    0.000000   NaN
# r_0454     0.0000         -0.000000    0.000000   NaN
# r_1054    -1.3650         -0.932580    0.432420    3.167909e+01
# r_0486     2.6985          1.837893    0.860607    3.189205e+01
# r_0450     1.3650          0.933942    0.431058    3.157932e+01
# r_0452     0.0000         -0.053366    0.053366    inf
# r_0302     0.0375         -999.855242  999.892742  2.666381e+06
# r_0892    -2.6985         -1.837893    0.860607    3.189205e+01
# r_0893    -2.6985         -0.872935    1.825565    6.765109e+01
# r_0889     0.2430          0.020629    0.222371    9.151076e+01
# r_1049    -0.0705         -0.004889    0.065611    9.306595e+01
# r_1048     0.1500          0.004889    0.145111    9.674100e+01
# r_1050    -0.1500         -0.032665    0.117335    7.822343e+01
# r_0466     0.2430          0.020629    0.222371    9.151076e+01
# r_0467     1.2150          1.076571    0.138429    1.139331e+01
# r_0886     1.3650          0.933942    0.431058    3.157932e+01
# r_0959     2.5395          0.025843    2.513657    9.898236e+01
# r_0163     2.3805          1.307884    1.072616    4.505841e+01
# r_2116     0.1590          0.000000    0.159000    1.000000e+02
# r_0112     0.1095          0.033984    0.075516    6.896394e+01
# r_0958     0.1335          0.301848    0.168348    1.261031e+02
# r_0366     2.6985          0.872935    1.825565    6.765109e+01
# r_0832     0.0000          0.000001    0.000001    inf
# r_0091     0.2430          0.020629    0.222371    9.151076e+01
# r_0718     0.0600          0.000000    0.060000    1.000000e+02
# r_1239     0.1275          0.000000    0.127500    1.000000e+02
# r_4041     0.3700          0.142086    0.227914    6.159835e+01

# %% [markdown]
# <p style="float: center; font-size: 9pt; text-align: center; width: 80%;"><img src = "Results/Case 9/b_fba_exp_sim_plot.png", width = 100%></p>

# %% [markdown]
# ## Parsimonious Flux Balance Analysis (pFBA) Simulation

# %%
b_pfba_res, b_pfba_exp_sim, b_pfba_exp_sim_errors = case9.simulationPipeline(b_exp_df, cs = 'glucose',type = 'pfba', res_exists = True, fname = 'Results/Case 9/res_pfba_batch_case9.sav')
pd.concat([reactions, b_pfba_exp_sim_errors], axis = 1, join = 'inner')
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0961     Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0959     Pyruvate <==> Acetaldehyde
# r_0163     Ethanol <==> Acetaldehyde
# r_2116     Acetaldehyde <==> Acetate
# r_0112     Acetate <==> Acetyl-CoA
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0718     (S)-Malate-mit <==> Pyruvate + CO2
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            batch exp flux  Sim Flux  Abs Error     Rel Error
# Yeast7_ID
# r_0534     1.5000          1.500000  0.000000   0.000000e+00
# r_0962    -2.6790         -0.797842  1.881158   7.021868e+01
# r_0961     0.0015          0.245150  0.243650   1.624335e+04
# r_2131     0.0375          0.107048  0.069548   1.854606e+02
# r_0713     0.0000          0.144757  0.144757   inf
# r_0300    -0.0375         -0.144757  0.107257   2.860187e+02
# r_1022     0.0000         -0.000000  0.000000  NaN
# r_0454     0.0000         -0.000000  0.000000  NaN
# r_1054    -1.3650         -0.932445  0.432555   3.168903e+01
# r_0486     2.6985          1.837763  0.860737   3.189685e+01
# r_0450     1.3650          0.928777  0.436223   3.195774e+01
# r_0452     0.0000         -0.053366  0.053366   inf
# r_0302     0.0375          0.107048  0.069548   1.854606e+02
# r_0892    -2.6985         -1.837763  0.860737   3.189685e+01
# r_0893    -2.6985         -0.872948  1.825552   6.765064e+01
# r_0889     0.2430          0.021052  0.221948   9.133645e+01
# r_1049    -0.0705         -0.005030  0.065470   9.286566e+01
# r_1048     0.1500          0.000000  0.150000   1.000000e+02
# r_1050    -0.1500          0.000000  0.150000   1.000000e+02
# r_0466     0.2430          0.021052  0.221948   9.133645e+01
# r_0467     1.2150          1.076152  0.138848   1.142784e+01
# r_0886     1.3650          0.928777  0.436223   3.195774e+01
# r_0959     2.5395          0.025769  2.513731   9.898526e+01
# r_0163     2.3805          0.000000  2.380500   1.000000e+02
# r_2116     0.1590          0.000652  0.158348   9.958969e+01
# r_0112     0.1095          0.033911  0.075589   6.903130e+01
# r_0958     0.1335          0.301845  0.168345   1.261009e+02
# r_0366     2.6985          0.872948  1.825552   6.765064e+01
# r_0832     0.0000          0.000001  0.000001   inf
# r_0091     0.2430          0.021052  0.221948   9.133645e+01
# r_0718     0.0600          0.000000  0.060000   1.000000e+02
# r_1239     0.1275          0.000000  0.127500   1.000000e+02
# r_4041     0.3700          0.142085  0.227915   6.159874e+01

# %% [markdown]
# <p style="float: center; font-size: 9pt; text-align: center; width: 80%;"><img src = "Results/Case 9/b_pfba_exp_sim_plot.png", width = 100%></p>

# %% [markdown]
# ## Flux Variability Analysis (FVA) Simulation

# %%
b_fva_res, b_fva_exp_sim, _ = case9.simulationPipeline(b_exp_df, cs = 'glucose', type = 'fva', res_exists = True, fname = 'Results/Case 9/res_fva_batch_case9.sav')
pd.concat([reactions, b_fva_exp_sim], axis = 1, join = 'inner')
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0961     Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0959     Pyruvate <==> Acetaldehyde
# r_0163     Ethanol <==> Acetaldehyde
# r_2116     Acetaldehyde <==> Acetate
# r_0112     Acetate <==> Acetyl-CoA
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0718     (S)-Malate-mit <==> Pyruvate + CO2
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            batch exp flux      maximum     minimum
# Yeast7_ID
# r_0534     1.5000          1.500511     1.499970
# r_0962    -2.6790         -0.799217    -0.797328
# r_0961     0.0015          0.246457     0.244476
# r_2131     0.0375          0.110557     0.104707
# r_0713     0.0000          1000.000000  0.143479
# r_0300    -0.0375         -0.146160    -0.144575
# r_1022     0.0000         -0.001404    -0.000000
# r_0454     0.0000         -5.805150    -0.000000
# r_1054    -1.3650         -0.935412    -0.931902
# r_0486     2.6985          1.840736     1.837226
# r_0450     1.3650          0.936774    -0.000702
# r_0452     0.0000         -0.054368    -0.052089
# r_0302     0.0375          1000.000000 -999.855246
# r_0892    -2.6985         -1.840736    -1.837226
# r_0893    -2.6985         -0.874322    -0.872433
# r_0889     0.2430          0.022698     0.012168
# r_1049    -0.0705         -0.005578    -0.002068
# r_1048     0.1500          0.005578    -0.934705
# r_1050    -0.1500         -0.031974    -0.035484
# r_0466     0.2430          0.022698     0.012168
# r_0467     1.2150          1.085040     1.074510
# r_0886     1.3650          0.936774     0.000000
# r_0959     2.5395          0.026419     0.025476
# r_0163     2.3805          1000.000000  0.000000
# r_2116     0.1590          0.001560     0.000000
# r_0112     0.1095          0.034920     0.033910
# r_0958     0.1335          0.315882     0.301530
# r_0366     2.6985          0.874322     0.872433
# r_0832     0.0000          0.001405     0.000000
# r_0091     0.2430          0.022698     0.012168
# r_0718     0.0600          0.003510     0.000000
# r_1239     0.1275          0.001276     0.000000
# r_4041     0.3700          0.142085     0.142083

# %% [markdown]
# # Chemostat culture

# %% [markdown]
# ## Flux Balance Analysis (FBA) Simulation

# %%
c_exp_df = case9.getColumnWithoutNAs(exp_dataset, 1, 'X')
# O2 flux estimation not possible (ethanol flux of 0 independently of O2 flux)

c_fba_res, c_fba_exp_sim, c_fba_exp_sim_errors = case9.simulationPipeline(c_exp_df, cs = 'glucose', type = 'fba', res_exists = True, fname = 'Results/Case 9/res_fba_chemostat_case9.sav')
pd.concat([reactions, c_fba_exp_sim_errors], axis = 1, join = 'inner') #Plot not showing r_0302
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0961     Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0959     Pyruvate <==> Acetaldehyde
# r_0163     Ethanol <==> Acetaldehyde
# r_2116     Acetaldehyde <==> Acetate
# r_0112     Acetate <==> Acetyl-CoA
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0718     (S)-Malate-mit <==> Pyruvate + CO2
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            chemostat exp flux    Sim Flux    Abs Error     Rel Error
# Yeast7_ID
# r_0534     1.5000              1.500000    0.000000     0.000000e+00
# r_0962    -1.8315             -0.797829    1.033671     5.643851e+01
# r_0961     0.5985              0.245058    0.353442     5.905459e+01
# r_2131     0.8985              0.107049    0.791451     8.808583e+01
# r_0713    -0.7365              0.144758    0.881258     1.196549e+02
# r_0300    -0.8985             -0.144758    0.753742     8.388888e+01
# r_1022    -0.7365             -0.000000    0.736500     1.000000e+02
# r_0454     0.7365             -0.000000    0.736500     1.000000e+02
# r_1054    -0.9045             -0.932580    0.028080     3.104520e+00
# r_0486     1.9065              1.837893    0.068607     3.598583e+00
# r_0450     0.9045              0.933942    0.029442     3.255083e+00
# r_0452    -0.7365             -0.053366    0.683134     9.275409e+01
# r_0302     0.8985             -999.855242  1000.753742  1.113805e+05
# r_0892    -1.9065             -1.837893    0.068607     3.598583e+00
# r_0893    -1.9065             -0.872935    1.033565     5.421268e+01
# r_0889     0.6630              0.020629    0.642371     9.688856e+01
# r_1049    -0.1815             -0.004889    0.176611     9.730661e+01
# r_1048     0.4005              0.004889    0.395611     9.877940e+01
# r_1050    -0.4005             -0.032665    0.367835     9.184398e+01
# r_0466     0.6630              0.020629    0.642371     9.688856e+01
# r_0467     0.5040              1.076571    0.572571     1.136054e+02
# r_0886     0.9045              0.933942    0.029442     3.255083e+00
# r_0959     0.6765              0.025843    0.650657     9.617990e+01
# r_0163     0.0000              1.307884    1.307884     inf
# r_2116     0.6870              0.000000    0.687000     1.000000e+02
# r_0112     0.6855              0.033984    0.651516     9.504238e+01
# r_0958     0.4095              0.301848    0.107652     2.628872e+01
# r_0366     1.9065              0.872935    1.033565     5.421268e+01
# r_0832     0.7365              0.000001    0.736499     9.999985e+01
# r_0091     0.6630              0.020629    0.642371     9.688856e+01
# r_0718     0.1005              0.000000    0.100500     1.000000e+02
# r_1239     2.3805              0.000000    2.380500     1.000000e+02
# r_4041     0.1000              0.142086    0.042086     4.208609e+01

# %% [markdown]
# <p style="float: center; font-size: 9pt; text-align: center; width: 80%;"><img src = "Results/Case 9/c_fba_exp_sim_plot.png", width = 100%></p>

# %% [markdown]
# ## Parsimonious Flux Balance Analysis (pFBA) Simulation

# %%
c_pfba_res, c_pfba_exp_sim, c_pfba_exp_sim_errors = case9.simulationPipeline(c_exp_df, cs = 'glucose',type = 'pfba', res_exists = True, fname = 'Results/Case 9/res_pfba_chemostat_case9.sav')
pd.concat([reactions, c_pfba_exp_sim_errors], axis = 1, join = 'inner')
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0961     Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0959     Pyruvate <==> Acetaldehyde
# r_0163     Ethanol <==> Acetaldehyde
# r_2116     Acetaldehyde <==> Acetate
# r_0112     Acetate <==> Acetyl-CoA
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0718     (S)-Malate-mit <==> Pyruvate + CO2
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            chemostat exp flux  Sim Flux  Abs Error   Rel Error
# Yeast7_ID
# r_0534     1.5000              1.500000  0.000000   0.000000
# r_0962    -1.8315             -0.797842  1.033658   56.437804
# r_0961     0.5985              0.245150  0.353350   59.039226
# r_2131     0.8985              0.107048  0.791452   88.085952
# r_0713    -0.7365              0.144757  0.881257   119.654718
# r_0300    -0.8985             -0.144757  0.753743   83.889038
# r_1022    -0.7365             -0.000000  0.736500   100.000000
# r_0454     0.7365             -0.000000  0.736500   100.000000
# r_1054    -0.9045             -0.932445  0.027945   3.089530
# r_0486     1.9065              1.837763  0.068737   3.605383
# r_0450     0.9045              0.928777  0.024277   2.684015
# r_0452    -0.7365             -0.053366  0.683134   92.754164
# r_0302     0.8985              0.107048  0.791452   88.085952
# r_0892    -1.9065             -1.837763  0.068737   3.605383
# r_0893    -1.9065             -0.872948  1.033552   54.212034
# r_0889     0.6630              0.021052  0.641948   96.824671
# r_1049    -0.1815             -0.005030  0.176470   97.228808
# r_1048     0.4005              0.000000  0.400500   100.000000
# r_1050    -0.4005              0.000000  0.400500   100.000000
# r_0466     0.6630              0.021052  0.641948   96.824671
# r_0467     0.5040              1.076152  0.572152   113.522172
# r_0886     0.9045              0.928777  0.024277   2.684015
# r_0959     0.6765              0.025769  0.650731   96.190795
# r_0163     0.0000              0.000000  0.000000  NaN
# r_2116     0.6870              0.000652  0.686348   99.905038
# r_0112     0.6855              0.033911  0.651589   95.053141
# r_0958     0.4095              0.301845  0.107655   26.289459
# r_0366     1.9065              0.872948  1.033552   54.212034
# r_0832     0.7365              0.000001  0.736499   99.999846
# r_0091     0.6630              0.021052  0.641948   96.824671
# r_0718     0.1005              0.000000  0.100500   100.000000
# r_1239     2.3805              0.000000  2.380500   100.000000
# r_4041     0.1000              0.142085  0.042085   42.084666

# %% [markdown]
# <p style="float: center; font-size: 9pt; text-align: center; width: 80%;"><img src = "Results/Case 9/c_pfba_exp_sim_plot.png", width = 100%></p>

# %% [markdown]
# ## Flux Variability Analysis (FVA) Simulation

# %%
c_fva_res, c_fva_exp_sim, _ = case9.simulationPipeline(c_exp_df, cs = 'glucose', type = 'fva', res_exists = True, fname = 'Results/Case 9/res_fva_chemostat_case9.sav')
pd.concat([reactions, c_fva_exp_sim], axis = 1, join = 'inner')
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0961     Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0959     Pyruvate <==> Acetaldehyde
# r_0163     Ethanol <==> Acetaldehyde
# r_2116     Acetaldehyde <==> Acetate
# r_0112     Acetate <==> Acetyl-CoA
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0718     (S)-Malate-mit <==> Pyruvate + CO2
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            chemostat exp flux      maximum     minimum
# Yeast7_ID
# r_0534     1.5000              1.500511     1.499970
# r_0962    -1.8315             -0.799217    -0.797328
# r_0961     0.5985              0.246457     0.244476
# r_2131     0.8985              0.110557     0.104707
# r_0713    -0.7365              1000.000000  0.143479
# r_0300    -0.8985             -0.146160    -0.144575
# r_1022    -0.7365             -0.001404    -0.000000
# r_0454     0.7365             -5.805150    -0.000000
# r_1054    -0.9045             -0.935412    -0.931902
# r_0486     1.9065              1.840736     1.837226
# r_0450     0.9045              0.936774    -0.000702
# r_0452    -0.7365             -0.054368    -0.052089
# r_0302     0.8985              1000.000000 -999.855246
# r_0892    -1.9065             -1.840736    -1.837226
# r_0893    -1.9065             -0.874322    -0.872433
# r_0889     0.6630              0.022698     0.012168
# r_1049    -0.1815             -0.005578    -0.002068
# r_1048     0.4005              0.005578    -0.934705
# r_1050    -0.4005             -0.031974    -0.035484
# r_0466     0.6630              0.022698     0.012168
# r_0467     0.5040              1.085040     1.074510
# r_0886     0.9045              0.936774     0.000000
# r_0959     0.6765              0.026419     0.025476
# r_0163     0.0000              1000.000000  0.000000
# r_2116     0.6870              0.001560     0.000000
# r_0112     0.6855              0.034920     0.033910
# r_0958     0.4095              0.315882     0.301530
# r_0366     1.9065              0.874322     0.872433
# r_0832     0.7365              0.001405     0.000000
# r_0091     0.6630              0.022698     0.012168
# r_0718     0.1005              0.003510     0.000000
# r_1239     2.3805              0.001276     0.000000
# r_4041     0.1000              0.142085     0.142083
