# %% [markdown]
# # Case 9 Report (Gombert et al, 2001)
#
# This report contains the results with case 9 simulations.
#
# Paper: [*Network Identification and Flux Quantification in the Central Metabolism of Saccharomyces cerevisiae under Different Conditions of Glucose Repression*](http://jb.asm.org/content/183/4/1441.long)
#
# **Abstract**
# The network structure and the metabolic fluxes in central carbon metabolism were characterized in aerobically
# grown cells of Saccharomyces cerevisiae. The cells were grown under both high and low glucose concentrations,
# i.e., either in a chemostat at steady state with a specific growth rate of 0.1 h ⴚ1 or in a batch culture with
# a specific growth rate of 0.37 h ⴚ1 . Experiments were carried out using [1- 13 C]glucose as the limiting substrate,
# and the resulting summed fractional labelings of intracellular metabolites were measured by gas chromatography
# coupled to mass spectrometry. The data were used as inputs to a flux estimation routine that involved
# appropriate mathematical modelling of the central carbon metabolism of S. cerevisiae. The results showed that
# the analysis is very robust, and it was possible to quantify the fluxes in the central carbon metabolism under
# both growth conditions. In the batch culture, 16.2 of every 100 molecules of glucose consumed by the cells entered
# the pentose-phosphate pathway, whereas the same relative flux was 44.2 per 100 molecules in the chemostat.
# The tricarboxylic acid cycle does not operate as a cycle in batch-growing cells, in contrast to the
# chemostat condition. Quantitative evidence was also found for threonine aldolase and malic enzyme activities,
# in accordance with published data. Disruption of the MIG1 gene did not cause changes in the metabolic network
# structure or in the flux pattern.
#
# **NOTES**
# - Wild-Type S.Cerevisiae CEN.PK 113-7D (MATa MAL2-8c SUC2) used in this study is very similar to that used to build the model (S288C)
# - O2 flux estimation not possible (ethanol flux of 0 independently of O2 flux)
#
# <p style="float: center; font-size: 9pt; text-align: center; width: 100%;"><img src = "Results/Case 9/gombert_2001_fig2", width = 80%></p>

# %%
import warnings
from case_9 import *

pd.set_option('display.max_colwidth', -1)
warnings.filterwarnings('ignore')

#Initialization
case9 = Case9()
case9.model = case9.loadObjectFromFile('model_yeast_76.sav')
case9.model.solver = 'optlang-cplex'
case9.setMedium('MINIMAL')
case9.dictsForCase9()

# %% [markdown]
# ## General datasets

# %%
#General datasets
exp_dataset, reactions = case9.loadExperimentalRes('Results/Case 9/case9_experimental_fluxes.csv')
pd.DataFrame(reactions)
# Out:
#                                                                                                                  Reaction
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0961     Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0959     Pyruvate <==> Acetaldehyde
# r_0163     Ethanol <==> Acetaldehyde
# r_2116     Acetaldehyde <==> Acetate
# r_0112     Acetate <==> Acetyl-CoA
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0718     (S)-Malate-mit <==> Pyruvate + CO2
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass

# %% [markdown]
# # Batch culture

# %% [markdown]
# ## Flux Balance Analysis (FBA) Simulation

# %%
b_exp_df = case9.getColumnWithoutNAs(exp_dataset, 0, 'X')
# O2 flux estimation not possible (ethanol flux of 0 independently of O2 flux)

b_fba_res, b_fba_exp_sim, b_fba_exp_sim_errors = case9.simulationPipeline(b_exp_df, cs = 'glucose', type = 'fba', res_exists = True, fname = 'Results/Case 9/res_fba_batch_case9.sav')
pd.concat([reactions, b_fba_exp_sim_errors], axis = 1, join = 'inner')
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0961     Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0959     Pyruvate <==> Acetaldehyde
# r_0163     Ethanol <==> Acetaldehyde
# r_2116     Acetaldehyde <==> Acetate
# r_0112     Acetate <==> Acetyl-CoA
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0718     (S)-Malate-mit <==> Pyruvate + CO2
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            batch exp flux    Sim Flux   Abs Error     Rel Error
# Yeast7_ID
# r_0534     1.5000          15.900000   14.400000   9.600000e+02
# r_0962    -2.6790         -8.456983    5.777983    2.156769e+02
# r_0961     0.0015          2.597618    2.596118    1.730745e+05
# r_2131     0.0375          1.134717    1.097217    2.925913e+03
# r_0713     0.0000          1.534439    1.534439    inf
# r_0300    -0.0375         -1.534439    1.496939    3.991839e+03
# r_1022     0.0000         -0.000000    0.000000   NaN
# r_0454     0.0000         -0.000000    0.000000   NaN
# r_1054    -1.3650         -9.885352    8.520352    6.242016e+02
# r_0486     2.6985          19.481666   16.783166   6.219443e+02
# r_0450     1.3650          9.899788    8.534788    6.252592e+02
# r_0452     0.0000         -0.565681    0.565681    inf
# r_0302     0.0375         -998.465561  998.503061  2.662675e+06
# r_0892    -2.6985         -19.481666   16.783166   6.219443e+02
# r_0893    -2.6985         -9.253115    6.554615    2.428984e+02
# r_0889     0.2430          0.218666    0.024334    1.001403e+01
# r_1049    -0.0705         -0.051818    0.018682    2.649911e+01
# r_1048     0.1500          0.051818    0.098182    6.545458e+01
# r_1050    -0.1500         -0.346247    0.196247    1.308316e+02
# r_0466     0.2430          0.218666    0.024334    1.001403e+01
# r_0467     1.2150          11.411656   10.196656   8.392309e+02
# r_0886     1.3650          9.899788    8.534788    6.252592e+02
# r_0959     2.5395          0.273935    2.265565    8.921302e+01
# r_0163     2.3805          13.863575   11.483075   4.823808e+02
# r_2116     0.1590          0.000000    0.159000    1.000000e+02
# r_0112     0.1095          0.360235    0.250735    2.289822e+02
# r_0958     0.1335          3.199585    3.066085    2.296693e+03
# r_0366     2.6985          9.253115    6.554615    2.428984e+02
# r_0832     0.0000          0.000012    0.000012    inf
# r_0091     0.2430          0.218666    0.024334    1.001403e+01
# r_0718     0.0600          0.000000    0.060000    1.000000e+02
# r_1239     0.1275          0.000000    0.127500    1.000000e+02
# r_4041     0.3700          1.506113    1.136113    3.070574e+02

# %% [markdown]
# <p style="float: center; font-size: 9pt; text-align: center; width: 80%;"><img src = "Results/Case 9/b_fba_exp_sim_plot.png", width = 100%></p>

# %% [markdown]
# ## Parsimonious Flux Balance Analysis (pFBA) Simulation

# %%
b_pfba_res, b_pfba_exp_sim, b_pfba_exp_sim_errors = case9.simulationPipeline(b_exp_df, cs = 'glucose',type = 'pfba', res_exists = True, fname = 'Results/Case 9/res_pfba_batch_case9.sav')
pd.concat([reactions, b_pfba_exp_sim_errors], axis = 1, join = 'inner')
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0961     Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0959     Pyruvate <==> Acetaldehyde
# r_0163     Ethanol <==> Acetaldehyde
# r_2116     Acetaldehyde <==> Acetate
# r_0112     Acetate <==> Acetyl-CoA
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0718     (S)-Malate-mit <==> Pyruvate + CO2
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            batch exp flux   Sim Flux  Abs Error     Rel Error
# Yeast7_ID
# r_0534     1.5000          15.900000  14.400000  9.600000e+02
# r_0962    -2.6790         -8.457121   5.778121   2.156820e+02
# r_0961     0.0015          2.598592   2.597092   1.731395e+05
# r_2131     0.0375          1.134706   1.097206   2.925882e+03
# r_0713     0.0000          1.534424   1.534424   inf
# r_0300    -0.0375         -1.534424   1.496924   3.991798e+03
# r_1022     0.0000         -0.000000   0.000000  NaN
# r_0454     0.0000         -0.000000   0.000000  NaN
# r_1054    -1.3650         -9.883915   8.518915   6.240963e+02
# r_0486     2.6985          19.480292  16.781792  6.218933e+02
# r_0450     1.3650          9.845035   8.480035   6.212480e+02
# r_0452     0.0000         -0.565675   0.565675   inf
# r_0302     0.0375          1.134706   1.097206   2.925882e+03
# r_0892    -2.6985         -19.480292  16.781792  6.218933e+02
# r_0893    -2.6985         -9.253244   6.554744   2.429033e+02
# r_0889     0.2430          0.223156   0.019844   8.166342e+00
# r_1049    -0.0705         -0.053315   0.017185   2.437594e+01
# r_1048     0.1500          0.000000   0.150000   1.000000e+02
# r_1050    -0.1500          0.000000   0.150000   1.000000e+02
# r_0466     0.2430          0.223156   0.019844   8.166342e+00
# r_0467     1.2150          11.407209  10.192209  8.388649e+02
# r_0886     1.3650          9.845035   8.480035   6.212480e+02
# r_0959     2.5395          0.273154   2.266346   8.924378e+01
# r_0163     2.3805          0.000000   2.380500   1.000000e+02
# r_2116     0.1590          0.006915   0.152085   9.565073e+01
# r_0112     0.1095          0.359454   0.249954   2.282682e+02
# r_0958     0.1335          3.199553   3.066053   2.296669e+03
# r_0366     2.6985          9.253244   6.554744   2.429033e+02
# r_0832     0.0000          0.000012   0.000012   inf
# r_0091     0.2430          0.223156   0.019844   8.166342e+00
# r_0718     0.0600          0.000000   0.060000   1.000000e+02
# r_1239     0.1275          0.000000   0.127500   1.000000e+02
# r_4041     0.3700          1.506097   1.136097   3.070534e+02

# %% [markdown]
# <p style="float: center; font-size: 9pt; text-align: center; width: 80%;"><img src = "Results/Case 9/b_pfba_exp_sim_plot.png", width = 100%></p>

# %% [markdown]
# ## Flux Variability Analysis (FVA) Simulation

# %%
b_fva_res, b_fva_exp_sim, _ = case9.simulationPipeline(b_exp_df, cs = 'glucose', type = 'fva', res_exists = True, fname = 'Results/Case 9/res_fva_batch_case9.sav')
pd.concat([reactions, b_fva_exp_sim], axis = 1, join = 'inner')
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0961     Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0959     Pyruvate <==> Acetaldehyde
# r_0163     Ethanol <==> Acetaldehyde
# r_2116     Acetaldehyde <==> Acetate
# r_0112     Acetate <==> Acetyl-CoA
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0718     (S)-Malate-mit <==> Pyruvate + CO2
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            batch exp flux      maximum     minimum
# Yeast7_ID
# r_0534     1.5000          15.905412    15.899682
# r_0962    -2.6790         -8.471697    -8.451675
# r_0961     0.0015          2.612448     2.591443
# r_2131     0.0375          1.171900     1.109891
# r_0713     0.0000          1000.000000  1.520878
# r_0300    -0.0375         -1.549291    -1.532491
# r_1022     0.0000         -0.014882    -0.000000
# r_0454     0.0000         -61.534587   -0.000000
# r_1054    -1.3650         -9.915364    -9.878158
# r_0486     2.6985          19.511804    19.474598
# r_0450     1.3650          9.929799    -0.007441
# r_0452     0.0000         -0.576300    -0.552140
# r_0302     0.0375          1000.000000 -998.465603
# r_0892    -2.6985         -19.511804   -19.474598
# r_0893    -2.6985         -9.267812    -9.247790
# r_0889     0.2430          0.240603     0.128986
# r_1049    -0.0705         -0.059131    -0.021925
# r_1048     0.1500          0.059131    -9.907874
# r_1050    -0.1500         -0.338927    -0.376132
# r_0466     0.2430          0.240603     0.128986
# r_0467     1.2150          11.501421    11.389804
# r_0886     1.3650          9.929799     0.000000
# r_0959     2.5395          0.280046     0.270046
# r_0163     2.3805          1000.000000  0.000000
# r_2116     0.1590          0.016536     0.000000
# r_0112     0.1095          0.370150     0.359450
# r_0958     0.1335          3.348345     3.196214
# r_0366     2.6985          9.267812     9.247790
# r_0832     0.0000          0.014894     0.000000
# r_0091     0.2430          0.240603     0.128986
# r_0718     0.0600          0.037206     0.000000
# r_1239     0.1275          0.013529     0.000000
# r_4041     0.3700          1.506097     1.506082

# %% [markdown]
# # Chemostat culture

# %% [markdown]
# ## Flux Balance Analysis (FBA) Simulation

# %%
c_exp_df = case9.getColumnWithoutNAs(exp_dataset, 1, 'X')
# O2 flux estimation not possible (ethanol flux of 0 independently of O2 flux)

c_fba_res, c_fba_exp_sim, c_fba_exp_sim_errors = case9.simulationPipeline(c_exp_df, cs = 'glucose', type = 'fba', res_exists = True, fname = 'Results/Case 9/res_fba_chemostat_case9.sav')
pd.concat([reactions, c_fba_exp_sim_errors], axis = 1, join = 'inner') #Plot not showing r_0302
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0961     Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0959     Pyruvate <==> Acetaldehyde
# r_0163     Ethanol <==> Acetaldehyde
# r_2116     Acetaldehyde <==> Acetate
# r_0112     Acetate <==> Acetyl-CoA
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0718     (S)-Malate-mit <==> Pyruvate + CO2
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            chemostat exp flux      Sim Flux    Abs Error     Rel Error
# Yeast7_ID
# r_0534     1.5000              1.170000e+00  0.330000     2.200000e+01
# r_0962    -1.8315             -6.223063e-01  1.209194     6.602204e+01
# r_0961     0.5985              1.911455e-01  0.407355     6.806258e+01
# r_2131     0.8985              8.349806e-02  0.815002     9.070695e+01
# r_0713    -0.7365              1.129116e-01  0.849412     1.153308e+02
# r_0300    -0.8985             -1.129116e-01  0.785588     8.743332e+01
# r_1022    -0.7365             -0.000000e+00  0.736500     1.000000e+02
# r_0454     0.7365             -0.000000e+00  0.736500     1.000000e+02
# r_1054    -0.9045             -7.274127e-01  0.177087     1.957847e+01
# r_0486     1.9065              1.433557e+00  0.472943     2.480690e+01
# r_0450     0.9045              7.284749e-01  0.176025     1.946104e+01
# r_0452    -0.7365             -4.162557e-02  0.694874     9.434819e+01
# r_0302     0.8985             -9.998871e+02  1000.785588  1.113840e+05
# r_0892    -1.9065             -1.433557e+00  0.472943     2.480690e+01
# r_0893    -1.9065             -6.808896e-01  1.225610     6.428589e+01
# r_0889     0.6630              1.609051e-02  0.646909     9.757308e+01
# r_1049    -0.1815             -3.813032e-03  0.177687     9.789916e+01
# r_1048     0.4005              3.813032e-03  0.396687     9.904793e+01
# r_1050    -0.4005             -2.547858e-02  0.375021     9.363831e+01
# r_0466     0.6630              1.609051e-02  0.646909     9.757308e+01
# r_0467     0.5040              8.397256e-01  0.335726     6.661222e+01
# r_0886     0.9045              7.284749e-01  0.176025     1.946104e+01
# r_0959     0.6765              2.015750e-02  0.656343     9.702033e+01
# r_0163     0.0000              1.020150e+00  1.020150     inf
# r_2116     0.6870              0.000000e+00  0.687000     1.000000e+02
# r_0112     0.6855              2.650789e-02  0.658992     9.613306e+01
# r_0958     0.4095              2.354412e-01  0.174059     4.250520e+01
# r_0366     1.9065              6.808896e-01  1.225610     6.428589e+01
# r_0832     0.7365              8.866172e-07  0.736499     9.999988e+01
# r_0091     0.6630              1.609051e-02  0.646909     9.757308e+01
# r_0718     0.1005              0.000000e+00  0.100500     1.000000e+02
# r_1239     2.3805              0.000000e+00  2.380500     1.000000e+02
# r_4041     0.1000              1.108271e-01  0.010827     1.082715e+01

# %% [markdown]
# <p style="float: center; font-size: 9pt; text-align: center; width: 80%;"><img src = "Results/Case 9/c_fba_exp_sim_plot.png", width = 100%></p>

# %% [markdown]
# ## Parsimonious Flux Balance Analysis (pFBA) Simulation

# %%
c_pfba_res, c_pfba_exp_sim, c_pfba_exp_sim_errors = case9.simulationPipeline(c_exp_df, cs = 'glucose',type = 'pfba', res_exists = True, fname = 'Results/Case 9/res_pfba_chemostat_case9.sav')
pd.concat([reactions, c_pfba_exp_sim_errors], axis = 1, join = 'inner')
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0961     Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0959     Pyruvate <==> Acetaldehyde
# r_0163     Ethanol <==> Acetaldehyde
# r_2116     Acetaldehyde <==> Acetate
# r_0112     Acetate <==> Acetyl-CoA
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0718     (S)-Malate-mit <==> Pyruvate + CO2
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            chemostat exp flux      Sim Flux  Abs Error   Rel Error
# Yeast7_ID
# r_0534     1.5000              1.170000e+00  0.330000   22.000000
# r_0962    -1.8315             -6.223165e-01  1.209184   66.021487
# r_0961     0.5985              1.912172e-01  0.407283   68.050596
# r_2131     0.8985              8.349722e-02  0.815003   90.707042
# r_0713    -0.7365              1.129105e-01  0.849410   115.330680
# r_0300    -0.8985             -1.129105e-01  0.785590   87.433450
# r_1022    -0.7365             -0.000000e+00  0.736500   100.000000
# r_0454     0.7365             -0.000000e+00  0.736500   100.000000
# r_1054    -0.9045             -7.273069e-01  0.177193   19.590167
# r_0486     1.9065              1.433455e+00  0.473045   24.812199
# r_0450     0.9045              7.244460e-01  0.180054   19.906468
# r_0452    -0.7365             -4.162515e-02  0.694875   94.348248
# r_0302     0.8985              8.349722e-02  0.815003   90.707042
# r_0892    -1.9065             -1.433455e+00  0.473045   24.812199
# r_0893    -1.9065             -6.808991e-01  1.225601   64.285386
# r_0889     0.6630              1.642090e-02  0.646579   97.523243
# r_1049    -0.1815             -3.923176e-03  0.177577   97.838470
# r_1048     0.4005              0.000000e+00  0.400500   100.000000
# r_1050    -0.4005              0.000000e+00  0.400500   100.000000
# r_0466     0.6630              1.642090e-02  0.646579   97.523243
# r_0467     0.5040              8.393984e-01  0.335398   66.547294
# r_0886     0.9045              7.244460e-01  0.180054   19.906468
# r_0959     0.6765              2.010003e-02  0.656400   97.028820
# r_0163     0.0000              0.000000e+00  0.000000  NaN
# r_2116     0.6870              5.088648e-04  0.686491   99.925929
# r_0112     0.6855              2.645036e-02  0.659050   96.141450
# r_0958     0.4095              2.354388e-01  0.174061   42.505778
# r_0366     1.9065              6.808991e-01  1.225601   64.285386
# r_0832     0.7365              8.866083e-07  0.736499   99.999880
# r_0091     0.6630              1.642090e-02  0.646579   97.523243
# r_0718     0.1005              0.000000e+00  0.100500   100.000000
# r_1239     2.3805              0.000000e+00  2.380500   100.000000
# r_4041     0.1000              1.108260e-01  0.010826   10.826040

# %% [markdown]
# <p style="float: center; font-size: 9pt; text-align: center; width: 80%;"><img src = "Results/Case 9/c_pfba_exp_sim_plot.png", width = 100%></p>

# %% [markdown]
# ## Flux Variability Analysis (FVA) Simulation

# %%
c_fva_res, c_fva_exp_sim, _ = case9.simulationPipeline(c_exp_df, cs = 'glucose', type = 'fva', res_exists = True, fname = 'Results/Case 9/res_fva_chemostat_case9.sav')
pd.concat([reactions, c_fva_exp_sim], axis = 1, join = 'inner')
# Out:
#                                                                                                                  Reaction  \
# Yeast7_ID
# r_0534     D-Glucose(ex) <==> D-Glucose-6-phosphate
# r_0962     Pyruvate <==> Phosphoenolpyruvate
# r_0961     Pyruvate-mit + CoA <==> Acetyl-CoA-mit + CO2-mit
# r_2131     Isocitrate <==> 2-Oxoglutarate + CO2-mit
# r_0713     (S)-Malate-mit <==> Oxaloacetate-mit
# r_0300     Citrate + CoA <==> Acetyl-CoA-mit + Oxaloacetate-mit
# r_1022     Succinate-mit + CoA <==> Succinyl-CoA
# r_0454     Succinate-mit <==> Fumarate
# r_1054     D-Glyceraldehyde-3-phosphate <==> Glycerone-phosphate
# r_0486     D-Glyceraldehyde-3-phosphate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0450     D-Fructose-1,6-bisphosphate <==> Glycerone-phosphate + D-Glyceraldehyde-3-phosphate
# r_0452     (S)-Malate-mit <==> Fumarate
# r_0302     Citrate <==> Isocitrate
# r_0892     3-Phospho-D-glycerate <==> 3-Phospho-D-glyceroyl-phosphate
# r_0893     2-Phospho-D-glycerate <==> 3-Phospho-D-glycerate
# r_0889     6-Phospho-D-gluconate <==> D-Ribulose-5-phosphate + CO2
# r_1049     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Ribose-5-phosphate + D-Xylulose-5-phosphate
# r_1048     Sedoheptulose-7-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Fructose-6-phosphate
# r_1050     D-Fructose-6-phosphate + D-Glyceraldehyde-3-phosphate <==> D-Erythrose-4-phosphate + D-Xylulose-5-phosphate
# r_0466     D-Glucose-6-phosphate <==> D-Glucono-1,5-lactone-6-phosphate
# r_0467     D-Glucose-6-phosphate <==> D-Fructose-6-phosphate
# r_0886     D-Fructose-6-phosphate <==> D-Fructose-1,6-bisphosphate
# r_0959     Pyruvate <==> Acetaldehyde
# r_0163     Ethanol <==> Acetaldehyde
# r_2116     Acetaldehyde <==> Acetate
# r_0112     Acetate <==> Acetyl-CoA
# r_0958     Pyruvate + CO2 <==> Oxaloacetate
# r_0366     2-Phospho-D-glycerate <==> Phosphoenolpyruvate
# r_0832     2-Oxoglutarate + CoA <==> Succinyl-CoA + CO2-mit
# r_0091     D-Glucono-1,5-lactone-6-phosphate <==> 6-Phospho-D-gluconate
# r_0718     (S)-Malate-mit <==> Pyruvate + CO2
# r_1239     Oxaloacetate <==> Oxaloacetate-mit
# r_4041     Biomass
#
#            chemostat exp flux      maximum     minimum
# Yeast7_ID
# r_0534     1.5000              1.170398     1.169977
# r_0962    -1.8315             -0.623389    -0.621916
# r_0961     0.5985              0.192237     0.190691
# r_2131     0.8985              0.086234     0.081671
# r_0713    -0.7365              1000.000000  0.111914
# r_0300    -0.8985             -0.114004    -0.112768
# r_1022    -0.7365             -0.001095    -0.000000
# r_0454     0.7365             -4.528017    -0.000000
# r_1054    -0.9045             -0.729621    -0.726883
# r_0486     1.9065              1.435774     1.433036
# r_0450     0.9045              0.730683    -0.000548
# r_0452    -0.7365             -0.042407    -0.040629
# r_0302     0.8985              1000.000000 -999.887092
# r_0892    -1.9065             -1.435774    -1.433036
# r_0893    -1.9065             -0.681971    -0.680498
# r_0889     0.6630              0.017705     0.009491
# r_1049    -0.1815             -0.004351    -0.001613
# r_1048     0.4005              0.004351    -0.729070
# r_1050    -0.4005             -0.024940    -0.027678
# r_0466     0.6630              0.017705     0.009491
# r_0467     0.5040              0.846331     0.838118
# r_0886     0.9045              0.730683     0.000000
# r_0959     0.6765              0.020607     0.019871
# r_0163     0.0000              1000.000000  0.000000
# r_2116     0.6870              0.001217     0.000000
# r_0112     0.6855              0.027237     0.026450
# r_0958     0.4095              0.246388     0.235193
# r_0366     1.9065              0.681971     0.680498
# r_0832     0.7365              0.001096     0.000000
# r_0091     0.6630              0.017705     0.009491
# r_0718     0.1005              0.002738     0.000000
# r_1239     2.3805              0.000996     0.000000
# r_4041     0.1000              0.110826     0.110825
